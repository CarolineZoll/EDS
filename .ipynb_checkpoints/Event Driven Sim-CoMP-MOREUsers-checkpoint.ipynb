# %% [markdown]
# Event Driven Simulation

# %%
# %reset
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])? y

# %% [markdown]
# Scheduling CoMP
# ---------

# %%
import simpy
import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import poisson

SCHEDULE_T=2 #Clock des Schedulers 
alpha=-np.log10(0.01)/100



def df_to_ue_lists(df,cluster,thr):

    cluster=[19,20]
    df_filter=df.groupby('PCI Serving')
    ue_dict={}
    for i in cluster:
        counter=0
        ue_list=np.array([])
        df2=df_filter.get_group(i)
        for j in df2.index:
            ue_list=np.append(ue_list, ue(df.iloc[j]['JT_1 SINR [lin]'],df.iloc[j]['JT_2 SINR [lin]'],df.iloc[j]['PCI Serving'],df.iloc[j]['PCI Coord'],env,df.iloc[j]['usage'], thr,df.iloc[j]['id']))
        ue_dict[i]= ue_list
    return ue_dict

#function to monitor the level of the different queues
def monitor(queue,monitor): 
    monitor.update({env.now: queue.level})
    return monitor

def calculate_prb_number(users,max_prb):
    count=0
    count2=0
    for i in np.arange(len(users)):
        if(users[i].comp ==1):
            if(users[i].qos==0):
                count+=1
            if(users[i].qos==1):
                count+=4
            if(users[i].qos==2):
                count+=75
                
        elif(users[i].comp ==0):
            if(users[i].qos==0):
                count2+=1
            if(users[i].qos==1):
                count2+=4
            if(users[i].qos==2):
                count2+=75
    prb_number=round(count/count2*max_prb)
    return prb_number

def get_dataframe(users):
    df=pd.DataFrame()
    sinr=np.array([])
    sinr2=np.array([])
    tbs=np.array([])
    queue=np.array([])
    
    for i in np.arange(np.size(users)):
        sinr=np.append(sinr,users[i].sinr)
        sinr2=np.append(sinr,users[i].sinr2)
        tbs=np.append(sinr,users[i].tbs)
        queue=np.append(sinr,users[i].queue)
    df['sinr']=sinr
    df['sinr2']=sinr2
    df['tbs']=tbs
    df['queue']=queue
    return df

def calculate_tbs(sinr,sinr2):
    sinr=int(sinr)
    sinr2=int(sinr2)
    if(sinr>30 or sinr2>30):
        print('sinr out of range')
        tbs=30
        tbs2=30
    elif(sinr<-10):
        print('sinr out of range')
        tbs=-10
        tbs2=-10
    else:
        mapping=pd.read_csv('Data/sinr-tbs-mapping.csv')
        tbs=mapping.iloc[sinr].values[1]
        tbs2=mapping.iloc[sinr2].values[1]
    return tbs,tbs2

def metric_list_nC(users,sched_exp,counter):
    e1=sched_exp[0]
    e2=sched_exp[1]
    metric=np.array([])

    for i in users: 
        if(i.qos==1 or i.qos==2):
            metric=np.append(metric, (alpha*i.queue.level*((i.cp)**e1/(i.mR)**e2)))  #list the metric of all UEs in the process 
            i.mR=(1-1/counter)*i.mR #Ratenanpassung für alle Nutzer    
        elif(i.qos==0):
            if(i.queue.level>0):
                metric=np.append(metric,((i.cp)**e1/(i.mR**e2)))
                i.mR=(1-1/counter)*i.mR #Ratenanpassung für alle Nutzer
            elif(i.queue2.level==0):
                metric=np.append(metric,0)
                i.mR=(1-1/counter)*i.mR #Ratenanpassung für alle Nutzer
    sched_user_list = (-metric).argsort() #sort UEs by metric that will be used for scheduling
    return sched_user_list

def metric_list_C(users,sched_exp,counter,usage):
    e1=sched_exp[0]
    e2=sched_exp[1]
    metric=np.array([])
    for i in users: 
        if(usage=='nocomp'):
            cp=i.cp
        elif(usage=='comp'):
            cp=i.cp2
            
        if(i.qos==1 or i.qos==2):
            metric=np.append(metric, (alpha*i.queue2.level*(cp**e1/(i.mR2)**e2)))  #list the metric of all UEs in the process 
            i.mR2=(1-1/counter)*i.mR2 #Ratenanpassung für alle Nutzer    
        elif(i.qos==0):
            if(i.queue2.level>0):
                metric=np.append(metric,((cp)**e1/(i.mR2)**e2))
                i.mR2=(1-1/counter)*i.mR2 #Ratenanpassung für alle Nutzer
            elif(i.queue2.level==0):
                metric=np.append(metric,0)
                i.mR2=(1-1/counter)*i.mR2 #Ratenanpassung für alle Nutzer
    sched_user_list = (-metric).argsort() #sort UEs by metric that will be used for scheduling
    return sched_user_list


def central_scheduler(env, users, SCHEDULE_T,cluster, prb_number):
    
    counter=1 #counts the number of scheduling procedures
    alpha=-np.log10(0.01)/100
    while True: #größte Warteschlange wird auch bedient
        
        yield env.timeout(SCHEDULE_T) #for each ms the scheduling is active -> per TTI
        metric=np.array([]) 
        
        for i in np.arange(len(users)):
            users[i].mon= monitor(users[i].queue,users[i].mon)
        
        sched_user_list=metric_list_C(users,[1,1],counter,'comp')
        
        remaining_prb_list={}
        for i in cluster:
            remaining_prb_list[i]=prb_number
            
        k=0
        free_res=1
        
        while(free_res==1):
            sched_user=sched_user_list[k]
            cell1=int(users[sched_user].cell1)
            cell2=int(users[sched_user].cell2)
            queue_size=users[sched_user].queue.level
            tbs=users[sched_user].tbs
            tbs2=users[sched_user].tbs2
            remaining_prbs=remaining_prb_list[cell1]
            remaining_prbs_c2=remaining_prb_list[cell2]
            #print('Resourcen:',remaining_prb_list[cell1])
            #print('Resourcen:',remaining_prb_list[cell2])
            #serving cell has no resources left -> no scheduling 
            if(remaining_prbs_c2==0):
                #print('keine Res mehr frei')
                continue
            #cell to coordinate with has no resources left -> without comp
            elif(remaining_prbs_c2==0):
                #print('ohne CoMP')
                sched_size=queue_size
                remaining_prb_list[cell1]=remaining_prbs-np.ceil(queue_size/tbs)
                
            elif((queue_size/tbs2)<=remaining_prbs and (queue_size/tbs2)<=remaining_prbs_c2 and queue_size>0):
            #comp can be used
                #print('mit CoMP')
                sched_size=queue_size
                remaining_prb_list[cell1]=remaining_prbs-np.ceil(queue_size/tbs2)
                remaining_prb_list[cell2]=remaining_prbs_c2-np.ceil(queue_size/tbs2)
            #one of the cells has not enough resources left 
            elif((queue_size/tbs2)>remaining_prbs or (queue_size/tbs2)>remaining_prbs_c2):
                #print('mit CoMP - v2')
                sched_size=min(remaining_prbs,remaining_prbs_c2)*tbs2
                remaining_prb_list[cell1]=remaining_prbs-np.ceil(sched_size/tbs2)
                remaining_prb_list[cell2]=remaining_prbs_c2-np.ceil(sched_size/tbs2)
                
            elif(queue_size==0):
                print('empty queue')
                break
            else:
                print('something went wrong')

            users[sched_user].mR=users[sched_user].mR+(1/counter)*sched_size
            users[sched_user].queue.get(sched_size)
            #print('Queue nachher:',users[sched_user].queue.level)
            k=k+1
            free_res=0
            for i in cluster:
                if(remaining_prb_list[i]!=0):
                    free_res=1
                    
        counter=counter+2
        
        


#scheduler takes packets from the queues according to the capacity of each user
def scheduler(env, users, SCHEDULE_T,cluster, prb_number, users2, prb_number2, sched_metric):
    
    counter=1 #counts the number of scheduling procedures
    bits1=0
    bits2=0
    while True: #größte Warteschlange wird auch bedient
        
        yield env.timeout(SCHEDULE_T) #for each ms the scheduling is active -> per TTI
        metric=np.array([]) 
        
        for i in np.arange(len(users)):
            users[i].mon= monitor(users[i].queue,users[i].mon)
        
        sched_user_list=metric_list_nC(users,[1,1],counter)

        remaining_prbs=prb_number
        k=0
        while(remaining_prbs>0):
            sched_user=sched_user_list[k]
            queue_size=users[sched_user].queue.level
            tbs=users[sched_user].tbs

            if((queue_size/tbs)<=remaining_prbs and queue_size>0):
                sched_size=queue_size
                remaining_prbs=remaining_prbs-np.ceil(queue_size/tbs)
            elif((queue_size/tbs)>remaining_prbs):
                sched_size=remaining_prbs*tbs
                remaining_prbs=remaining_prbs-np.ceil(sched_size/tbs)
                
            elif(queue_size==0):
                print('empty queue')
                break
            else:
                print('something went wrong')
          
            users[sched_user].mR=users[sched_user].mR+(1/counter)*sched_size
            users[sched_user].queue.get(sched_size)
            users[sched_user].bits+=sched_size
            k=k+1
            
            if(sched_user_list[k]==0 or sched_user_list[k]==1 or sched_user_list[k] ==2):
                print('ue-number sched1:', sched_user_list[k])
                print(users[sched_user].mR)
                print(counter)
        #CoMP-Scheduling Process- Users with normal scheduling
        ############################
        
        sched_user_list = metric_list_C(users2,[1,1],counter,'nocomp') #calculates the ordered list with ues
        
        
        remaining_prbs=prb_number2
        k=0
        #print('New scheduling round')
        while(remaining_prbs>0):
            sched_user=sched_user_list[k]
            queue_size=users2[sched_user].queue2.level
            tbs=users2[sched_user].tbs

            if((queue_size/tbs)<=remaining_prbs and queue_size>0):
                sched_size=queue_size
                remaining_prbs=remaining_prbs-np.ceil(queue_size/tbs)
            elif((queue_size/tbs)>remaining_prbs):
                sched_size=remaining_prbs*tbs
                remaining_prbs=remaining_prbs-np.ceil(sched_size/tbs)
                
            elif(queue_size==0):
                print('empty queue')
                break
            else:
                print('something went wrong')
            
            users2[sched_user].mR2=users2[sched_user].mR2+(1/counter)*sched_size
            users2[sched_user].queue2.get(sched_size)
            users2[sched_user].bits2+=sched_size
            
            if(sched_user_list[k]==0 or sched_user_list[k]==1 or sched_user_list[k] ==2):
                print('ue-number sched1:', sched_user_list[k])
                print(users2[sched_user].mR2)
                print(counter)
            
            k=k+1
        ###########################

        counter=counter+2
        

class ue:
    def __init__(self,sinr,sinr2,cell1,cell2,env,qos,thr,id):
        self.sinr=sinr
        self.sinr2=sinr2
        self.tbs,self.tbs2=calculate_tbs(sinr,sinr2)
        self.qos=qos
        self.cp=0.5*0.7*20000000*np.log2(1+np.power(10,sinr/10))/8000
        self.cp2=0.5*0.7*20000000*np.log2(1+np.power(10,sinr2/10))/8000 #division by 8000 to determine number of bits that can be transmitted per TTI (1ms)
        self.cell1=cell1
        self.cell2=cell2
        self.mR=0.1 #mittlere Rate
        self.mR2=0.1 #mittlere Rate
        self.queue=simpy.Container(env)
        self.queue2=simpy.Container(env)
        self.mon={}
        self.metric=self.sinr+self.queue.level
        self.metric2=self.sinr+self.queue.level
        self.gain=self.sinr2-self.sinr
        self.id=id
        self.bits=0
        self.bits2=0
        if(self.gain >thr):
            self.comp=np.array(1)
        else:
            self.comp=np.array(0) 
        
    def rt_user(self,env):
        on_off=1
        counter=0
        start=0
        while True:
            if(start==0):
                start=1
                yield env.timeout(random.randint(0,200))
            elif(on_off==1 and counter<3000):
                self.queue.put(160) #20 bytes
                self.queue2.put(160) #20 bytes
                mon= monitor(self.queue,self.mon)
                #yield env.timeout(poisson.rvs(6, 1))
                #print('On Phase')
                #print(self.queue.level)
                counter=counter+20
                #print(counter)
                yield env.timeout(20) #every 20ms new packet
            elif(on_off==0):
                on_off=1

                yield env.timeout(3000) #3s no packet to be sent
            elif(on_off==1 and counter>=3000):
                on_off=0
                counter=0
                #print('change from ON-OFF')
            
    def user_packets(self,env,packet_arr):
        while True:
            #print('o-user')
            self.queue.put(2000)
            self.queue2.put(2000) 
            #self.mon= monitor(self.queue,self.mon)
            yield env.timeout(poisson.rvs(packet_arr, 1))
            

    def streaming_user(self,env):
        while True:
            #print('o-user')
            self.queue.put(150) #1080p-> 1.5 Mbps (normal 1500)
            self.queue2.put(150) #1080p-> 1.5 Mbps 
            #self.mon= monitor(self.queue,self.mon)
            yield env.timeout(2)
    
    #Noch sehr vereinfacht!!!
    def sinr_variator(self,env):
        change=round(np.random.normal(0,0.5))
        if((self.sinr+change)>-10 and (self.sinr+change)<30): 
            self.sinr=self.sinr +change
            self.sinr2=self.sinr2+change 
        yield env.timeout(2000)

# %%
env=simpy.Environment()
#env = simpy.rt.RealtimeEnvironment(factor=1/10)

ue_list=np.array([])
ue_list2=np.array([])
#define UEs

    
max_prb=50
thr=6
cluster=[19,20]


x=np.append(np.ones(70)*19,np.ones(70)*20)
y=np.append(np.ones(70)*20,np.ones(70)*19)
sinr=np.random.randint(0,12,70*2)
sinr2=np.random.randint(2,16,70*2)
rt_nrt=np.array([])
rt_nrt=np.append(rt_nrt,np.ones(50)*0)
rt_nrt=np.append(rt_nrt,2)
rt_nrt=np.append(rt_nrt,2)
rt_nrt=np.append(rt_nrt,1)
rt_nrt=np.append(rt_nrt,np.ones(17))

rt_nrt=np.append(rt_nrt,np.ones(50)*0)
rt_nrt=np.append(rt_nrt,2)
rt_nrt=np.append(rt_nrt,2)
rt_nrt=np.append(rt_nrt,1)
rt_nrt=np.append(rt_nrt,np.ones(17))


df=pd.DataFrame()
df['PCI Serving']=x
df['PCI Coord']=y
df['JT_1 SINR [lin]']=sinr
df['JT_2 SINR [lin]']=sinr2
df['usage']=rt_nrt
df['id']=np.arange(0,140)
   
df['PCI Serving']=df['PCI Serving'].astype('int')
df['PCI Coord']=df['PCI Coord'].astype('int')

df['JT_1 SINR [lin]']=df['JT_1 SINR [lin]'].astype('int')
df['JT_2 SINR [lin]']=df['JT_2 SINR [lin]'].astype('int')


ue_dict=df_to_ue_lists(df,[19,20],6)
ue_all=np.array([])
for i in cluster:
    ue_all=np.append(ue_all,ue_dict[i])

prb_number_comp=calculate_prb_number(ue_all,max_prb)
prb_number_normal=max_prb-prb_number_comp

# %%
#Start processes
    
for i in cluster:
    ue_list=ue_dict[i]
    for j in np.arange(0,50):
        env.process(ue_list[j].user_packets(env,50))
        #env.process(ue_list[i].sinr_variator()) #movement
    env.process(ue_list[50].streaming_user(env))
    env.process(ue_list[51].streaming_user(env))
    #env.process(ue_list[100].sinr_variator()) #movement   
    for j in np.arange(52,70):
        env.process(ue_list[j].rt_user(env))
        #env.process(ue_list[i].sinr_variator()) #movement

        
ue_comp=np.array([]) #ues that use comp -> processed be central_scheduler
for i in cluster:
    ue_list=ue_dict[i]
    new_ue_list=np.array([])
    for j in ue_list:
        if(j.comp == 0):
            new_ue_list=np.append(new_ue_list,j)
        else:
            ue_comp=np.append(ue_comp,j)
    ue_dict[i]=new_ue_list #user without comp
    
env.process(central_scheduler(env,ue_comp,SCHEDULE_T,[19,20],prb_number_comp))

counter=0
for i in cluster:
    ue_list=ue_dict[i]
    ue_19=ue_all[counter*70:((counter+1)*70-1)]
    env.process(scheduler(env,ue_list,SCHEDULE_T,[19,20],prb_number_normal,ue_19,50,1))
env.run(until=5000)
# Out:
# <ipython-input-59-431104769901>:123: RuntimeWarning: divide by zero encountered in double_scalars
#   metric=np.append(metric,((cp)**e1/(i.mR2)**e2))
# <ipython-input-59-431104769901>:119: RuntimeWarning: divide by zero encountered in double_scalars
#   metric=np.append(metric, (alpha*i.queue2.level*(cp**e1/(i.mR2)**e2)))  #list the metric of all UEs in the process
# <ipython-input-59-431104769901>:119: RuntimeWarning: invalid value encountered in double_scalars
#   metric=np.append(metric, (alpha*i.queue2.level*(cp**e1/(i.mR2)**e2)))  #list the metric of all UEs in the process
# <ipython-input-59-431104769901>:100: RuntimeWarning: divide by zero encountered in double_scalars
#   metric=np.append(metric,((i.cp)**e1/(i.mR**e2)))
# <ipython-input-59-431104769901>:96: RuntimeWarning: divide by zero encountered in double_scalars
#   metric=np.append(metric, (alpha*i.queue.level*((i.cp)**e1/(i.mR)**e2)))  #list the metric of all UEs in the process
# <ipython-input-59-431104769901>:96: RuntimeWarning: invalid value encountered in double_scalars
#   metric=np.append(metric, (alpha*i.queue.level*((i.cp)**e1/(i.mR)**e2)))  #list the metric of all UEs in the process
# ue-number sched1: 1
# 200.0
# 1
# ue-number sched1: 0
# 2000.0
# 1
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 1
# 71.42857142857143
# 21
# empty queue
# ue-number sched1: 2
# 48.0
# 21
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 2
# 49.067503622239094
# 41
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 1
# 39.75772706019815
# 49
# empty queue
# empty queue
# empty queue
# ue-number sched1: 2
# 18.18181818181818
# 55
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 1
# 54.1736185252326
# 73
# empty queue
# ue-number sched1: 0
# 68.27625302880811
# 75
# empty queue
# empty queue
# ue-number sched1: 2
# 50.93166165720406
# 79
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 1
# 21.505376344086024
# 93
# empty queue
# ue-number sched1: 1
# 18.298969072164947
# 97
# empty queue
# empty queue
# ue-number sched1: 2
# 20.792079207920793
# 101
# empty queue
# ue-number sched1: 0
# 69.22336929135332
# 103
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 2
# 19.186010321686005
# 111
# empty queue
# ue-number sched1: 2
# 118.62331947183301
# 113
# empty queue
# empty queue
# empty queue
# ue-number sched1: 1
# 49.574202962628135
# 121
# empty queue
# ue-number sched1: 1
# 37.63984053436829
# 123
# empty queue
# ue-number sched1: 1
# 120.13026290601725
# 125
# empty queue
# empty queue
# empty queue
# ue-number sched1: 2
# 46.058946728865024
# 131
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 61.34698100604386
# 149
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 1
# 47.60886706316791
# 165
# empty queue
# empty queue
# empty queue
# ue-number sched1: 2
# 12.815888549311879
# 173
# empty queue
# ue-number sched1: 2
# 4.056041096410482
# 175
# empty queue
# empty queue
# empty queue
# ue-number sched1: 1
# 21.465247959772373
# 181
# empty queue
# ue-number sched1: 1
# 1.800876692689183
# 183
# empty queue
# ue-number sched1: 2
# 33.10512291649159
# 185
# ue-number sched1: 2
# 38.09386557469217
# 187
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 53.5574070895514
# 209
# empty queue
# ue-number sched1: 1
# 40.33485448374637
# 211
# empty queue
# empty queue
# empty queue
# ue-number sched1: 2
# 39.82524692928469
# 217
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 1
# 10.472822687638269
# 225
# ue-number sched1: 1
# 11.06989679810433
# 227
# empty queue
# ue-number sched1: 1
# 30.248109637873867
# 229
# ue-number sched1: 1
# 43.50322986852041
# 229
# empty queue
# ue-number sched1: 1
# 10.96195109939394
# 231
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 2
# 19.515910844868635
# 249
# empty queue
# ue-number sched1: 2
# 11.154512357503549
# 251
# empty queue
# empty queue
# empty queue
# ue-number sched1: 2
# 34.58734856160904
# 257
# empty queue
# empty queue
# ue-number sched1: 0
# 50.52918749514085
# 261
# ue-number sched1: 1
# 39.520715858632634
# 261
# empty queue
# empty queue
# ue-number sched1: 2
# 36.907475398336594
# 267
# empty queue
# empty queue
# ue-number sched1: 1
# 44.153638465750085
# 271
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 2
# 35.90688941856643
# 291
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 1
# 11.43950779047202
# 307
# empty queue
# ue-number sched1: 1
# 130.84118103871188
# 309
# empty queue
# empty queue
# ue-number sched1: 2
# 35.64108919445793
# 313
# empty queue
# ue-number sched1: 0
# 48.202403514090356
# 315
# ue-number sched1: 1
# 38.15466714157061
# 315
# empty queue
# ue-number sched1: 1
# 44.06574293792033
# 317
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 2
# 36.84130357190137
# 329
# empty queue
# empty queue
# empty queue
# ue-number sched1: 2
# 24.839252644506423
# 335
# empty queue
# ue-number sched1: 2
# 131.6432859208912
# 337
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 2
# 35.83007208985237
# 357
# empty queue
# empty queue
# empty queue
# ue-number sched1: 1
# 43.99898849168443
# 363
# empty queue
# empty queue
# ue-number sched1: 0
# 42.08875310883833
# 367
# ue-number sched1: 0
# 46.698184299277465
# 367
# empty queue
# empty queue
# ue-number sched1: 2
# 40.043611387291875
# 371
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 1
# 12.195034372233003
# 383
# empty queue
# ue-number sched1: 1
# 132.81071748392895
# 385
# ue-number sched1: 2
# 11.603219106845808
# 387
# empty queue
# ue-number sched1: 2
# 132.89821204661177
# 389
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 1
# 44.16218996359818
# 407
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 45.03863620736228
# 425
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 2
# 37.13416887730511
# 435
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 2
# 33.099579895625965
# 455
# empty queue
# ue-number sched1: 2
# 134.20652891244487
# 457
# ue-number sched1: 1
# 43.71209484846835
# 457
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 2
# 36.27131244161921
# 465
# ue-number sched1: 1
# 11.685927217982302
# 467
# empty queue
# ue-number sched1: 1
# 134.40758716788812
# 469
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 42.664970360237696
# 485
# ue-number sched1: 0
# 43.5898879471238
# 485
# empty queue
# ue-number sched1: 2
# 38.18214886854321
# 487
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 1
# 43.52179179355093
# 505
# empty queue
# ue-number sched1: 2
# 29.894920478328153
# 507
# empty queue
# ue-number sched1: 2
# 135.0260204932673
# 509
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 43.82410572381932
# 529
# empty queue
# empty queue
# empty queue
# ue-number sched1: 2
# 38.606391436703404
# 535
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 1
# 22.18430372352663
# 547
# empty queue
# ue-number sched1: 1
# 135.57606383513715
# 549
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 1
# 40.215755059819486
# 559
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 1
# 39.77449113663424
# 575
# empty queue
# empty queue
# ue-number sched1: 0
# 43.49059224961281
# 579
# ue-number sched1: 1
# 41.41743534368208
# 579
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 2
# 36.72800095488722
# 591
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 2
# 14.481780865283827
# 599
# empty queue
# ue-number sched1: 2
# 136.20786654203803
# 601
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 1
# 42.384736863597766
# 613
# empty queue
# empty queue
# ue-number sched1: 1
# 26.039209771298133
# 617
# empty queue
# ue-number sched1: 1
# 20.82497330119818
# 619
# empty queue
# empty queue
# empty queue
# ue-number sched1: 2
# 35.40359614015965
# 625
# empty queue
# ue-number sched1: 0
# 43.210363538799875
# 629
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 2
# 38.033879217514794
# 637
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 1
# 42.23569502710986
# 659
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 43.22643232912548
# 675
# empty queue
# ue-number sched1: 2
# 16.12888995446553
# 677
# empty queue
# ue-number sched1: 2
# 20.602046381676974
# 679
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 2
# 36.725295658898666
# 695
# empty queue
# ue-number sched1: 1
# 40.43683554826235
# 697
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 1
# 40.46062254940126
# 705
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 43.481969533774055
# 717
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 1
# 10.485054260152351
# 725
# ue-number sched1: 1
# 13.165890320816148
# 727
# empty queue
# ue-number sched1: 1
# 14.26296497611813
# 729
# ue-number sched1: 1
# 41.13160954138098
# 729
# empty queue
# ue-number sched1: 1
# 13.090094251482089
# 731
# empty queue
# empty queue
# empty queue
# ue-number sched1: 2
# 37.43337876347927
# 737
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 1
# 42.01742860556016
# 761
# empty queue
# empty queue
# ue-number sched1: 0
# 43.36628020066857
# 765
# empty queue
# empty queue
# empty queue
# ue-number sched1: 2
# 31.71365669994549
# 771
# empty queue
# ue-number sched1: 2
# 137.8246114181095
# 773
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 2
# 36.52550939116428
# 791
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 43.80345659384684
# 803
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 1
# 41.90448742110807
# 811
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 1
# 30.927192815288997
# 823
# empty queue
# ue-number sched1: 1
# 138.21132088229584
# 825
# empty queue
# empty queue
# ue-number sched1: 2
# 36.059601226166976
# 829
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 43.78443594702035
# 849
# empty queue
# empty queue
# ue-number sched1: 2
# 23.647824085741455
# 853
# empty queue
# ue-number sched1: 2
# 10.489882157203809
# 855
# empty queue
# ue-number sched1: 2
# 37.290476291404204
# 857
# empty queue
# ue-number sched1: 1
# 40.774529093740526
# 859
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 1
# 40.72421696941531
# 891
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 43.57259817500271
# 899
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 1
# 10.377814058525834
# 909
# empty queue
# ue-number sched1: 1
# 13.384060362112878
# 911
# ue-number sched1: 2
# 37.38643623089847
# 911
# empty queue
# ue-number sched1: 1
# 40.99184556656154
# 913
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 43.70793250468993
# 941
# empty queue
# empty queue
# ue-number sched1: 1
# 42.20662057606669
# 945
# empty queue
# empty queue
# ue-number sched1: 2
# 14.132140189398983
# 949
# empty queue
# ue-number sched1: 2
# 13.438000864170446
# 951
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 2
# 36.42521181196407
# 981
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 1
# 33.879690778415615
# 1001
# empty queue
# ue-number sched1: 1
# 9.833238769935543
# 1003
# empty queue
# ue-number sched1: 1
# 39.88708095794989
# 1005
# empty queue
# ue-number sched1: 0
# 41.149684341268845
# 1007
# ue-number sched1: 0
# 42.830518815607206
# 1007
# empty queue
# empty queue
# empty queue
# ue-number sched1: 1
# 42.04015188922503
# 1013
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 2
# 35.65873661885906
# 1027
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 2
# 33.36227117889176
# 1043
# empty queue
# ue-number sched1: 2
# 139.51582044551748
# 1045
# empty queue
# empty queue
# ue-number sched1: 2
# 35.157761825448794
# 1051
# empty queue
# empty queue
# ue-number sched1: 1
# 10.419442182801546
# 1055
# empty queue
# ue-number sched1: 1
# 139.5750690032357
# 1057
# empty queue
# empty queue
# empty queue
# ue-number sched1: 2
# 36.70352603284415
# 1063
# empty queue
# empty queue
# ue-number sched1: 0
# 40.71063523845203
# 1067
# ue-number sched1: 0
# 42.297363790243544
# 1067
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 1
# 41.94221972199311
# 1075
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 42.38342113004044
# 1113
# empty queue
# empty queue
# ue-number sched1: 2
# 36.8099690028499
# 1117
# empty queue
# ue-number sched1: 2
# 10.406772338440692
# 1119
# empty queue
# ue-number sched1: 2
# 139.87490111306928
# 1121
# empty queue
# ue-number sched1: 1
# 30.661874848364874
# 1123
# empty queue
# ue-number sched1: 1
# 139.89279057360073
# 1125
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 1
# 41.85490743935416
# 1137
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 41.991200901704296
# 1171
# ue-number sched1: 2
# 36.90656201539435
# 1171
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 1
# 41.762805985710415
# 1197
# empty queue
# empty queue
# ue-number sched1: 2
# 33.59373798904606
# 1201
# empty queue
# ue-number sched1: 2
# 10.363235753508407
# 1203
# empty queue
# empty queue
# empty queue
# ue-number sched1: 1
# 16.139599336077115
# 1211
# empty queue
# ue-number sched1: 1
# 140.26379100605573
# 1213
# empty queue
# ue-number sched1: 0
# 42.11599559741663
# 1215
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 2
# 35.7123311564125
# 1229
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 2
# 22.374196423586927
# 1247
# empty queue
# ue-number sched1: 2
# 140.40418973930642
# 1249
# empty queue
# empty queue
# empty queue
# ue-number sched1: 2
# 36.646075634422246
# 1255
# empty queue
# empty queue
# empty queue
# ue-number sched1: 1
# 40.42887714842573
# 1261
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 41.70191537368454
# 1275
# empty queue
# ue-number sched1: 1
# 41.84858126923103
# 1277
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 1
# 10.332216886162518
# 1305
# empty queue
# ue-number sched1: 1
# 13.86728692867606
# 1307
# empty queue
# empty queue
# ue-number sched1: 1
# 31.006815995737867
# 1311
# empty queue
# ue-number sched1: 1
# 140.63944176080545
# 1313
# ue-number sched1: 2
# 36.62729194478432
# 1313
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 2
# 18.134207889600912
# 1323
# empty queue
# ue-number sched1: 2
# 140.68165165716593
# 1325
# ue-number sched1: 0
# 41.63709740873708
# 1325
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 1
# 41.53060554652682
# 1347
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 41.69836216359038
# 1371
# ue-number sched1: 2
# 35.26215104759271
# 1371
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 2
# 35.3013135384935
# 1379
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 2
# 35.824828256064016
# 1395
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 1
# 33.21782808115474
# 1403
# ue-number sched1: 1
# 41.334678911707776
# 1403
# empty queue
# ue-number sched1: 1
# 140.94914665630938
# 1405
# ue-number sched1: 2
# 18.27602741263355
# 1405
# empty queue
# ue-number sched1: 2
# 13.942530621247506
# 1407
# empty queue
# empty queue
# ue-number sched1: 2
# 12.109687332211813
# 1411
# empty queue
# ue-number sched1: 2
# 140.97464480660142
# 1413
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 2
# 35.35578528444431
# 1423
# empty queue
# empty queue
# ue-number sched1: 0
# 41.46295387039816
# 1427
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 2
# 36.44822462136994
# 1437
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 1
# 41.17592347314983
# 1457
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 1
# 18.250846668637827
# 1485
# empty queue
# ue-number sched1: 1
# 13.99726930098895
# 1487
# empty queue
# ue-number sched1: 2
# 36.58612170655056
# 1489
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 1
# 13.891502207540258
# 1497
# empty queue
# ue-number sched1: 1
# 19.074721509909992
# 1499
# ue-number sched1: 0
# 40.80496200363554
# 1499
# empty queue
# empty queue
# empty queue
# ue-number sched1: 1
# 41.19201138195684
# 1505
# empty queue
# empty queue
# ue-number sched1: 2
# 18.168216956258252
# 1509
# empty queue
# ue-number sched1: 2
# 13.954911097027141
# 1511
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 40.88416167954514
# 1545
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 2
# 36.43109407172726
# 1553
# empty queue
# ue-number sched1: 1
# 40.18947870368336
# 1555
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 1
# 40.89122542186809
# 1565
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 40.985343812505384
# 1589
# empty queue
# empty queue
# empty queue
# ue-number sched1: 2
# 20.5221316241122
# 1595
# empty queue
# ue-number sched1: 2
# 141.5073487957391
# 1597
# empty queue
# ue-number sched1: 1
# 10.335950904539533
# 1599
# empty queue
# ue-number sched1: 1
# 141.51790270267517
# 1601
# empty queue
# empty queue
# empty queue
# ue-number sched1: 1
# 40.13397768939579
# 1607
# empty queue
# empty queue
# ue-number sched1: 2
# 36.42342948602315
# 1611
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 1
# 40.478883323826196
# 1619
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 41.080210912582054
# 1635
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 1
# 41.334439462002706
# 1645
# empty queue
# empty queue
# ue-number sched1: 2
# 18.17950291925298
# 1649
# empty queue
# ue-number sched1: 2
# 14.041543617052167
# 1651
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 10.34267856371371
# 1659
# empty queue
# ue-number sched1: 0
# 141.67162560938482
# 1661
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 2
# 35.75791306787946
# 1669
# empty queue
# empty queue
# ue-number sched1: 0
# 41.04867169008426
# 1673
# ue-number sched1: 0
# 41.317769913820015
# 1673
# empty queue
# empty queue
# empty queue
# ue-number sched1: 1
# 33.54883474559242
# 1679
# empty queue
# ue-number sched1: 1
# 141.72103555215006
# 1681
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 2
# 35.974277789889484
# 1693
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 1
# 40.95724217779377
# 1709
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 41.3993122393928
# 1719
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 2
# 35.71464603029582
# 1731
# empty queue
# empty queue
# empty queue
# ue-number sched1: 2
# 33.13150992855368
# 1737
# empty queue
# ue-number sched1: 2
# 18.85156004254789
# 1739
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 22.718323217110374
# 1757
# ue-number sched1: 1
# 40.97694157397132
# 1757
# empty queue
# ue-number sched1: 0
# 18.835073041140376
# 1759
# ue-number sched1: 2
# 35.4802545183426
# 1759
# empty queue
# ue-number sched1: 1
# 22.82718843576926
# 1761
# empty queue
# ue-number sched1: 1
# 11.334869747574274
# 1763
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 41.26609507788199
# 1773
# empty queue
# ue-number sched1: 2
# 35.87020146807589
# 1775
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 1
# 40.95022316940341
# 1807
# empty queue
# ue-number sched1: 0
# 41.55023521693651
# 1809
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 1
# 25.183791622161323
# 1817
# ue-number sched1: 2
# 35.622538108083795
# 1817
# empty queue
# ue-number sched1: 1
# 18.787268827915042
# 1819
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 2
# 35.341867279587795
# 1835
# empty queue
# empty queue
# ue-number sched1: 2
# 35.35637025231731
# 1839
# empty queue
# ue-number sched1: 2
# 15.925910542586001
# 1841
# empty queue
# ue-number sched1: 2
# 11.43634162385984
# 1843
# empty queue
# empty queue
# empty queue
# ue-number sched1: 2
# 35.505927800706324
# 1849
# empty queue
# empty queue
# ue-number sched1: 0
# 41.642677635633994
# 1853
# empty queue
# empty queue
# ue-number sched1: 1
# 40.83870434222188
# 1857
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 2
# 35.651803114160046
# 1865
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 13.869307192081259
# 1881
# ue-number sched1: 2
# 36.46505286401192
# 1881
# empty queue
# ue-number sched1: 0
# 11.484649406633647
# 1883
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 1
# 41.202864962833296
# 1893
# empty queue
# empty queue
# empty queue
# ue-number sched1: 2
# 25.409749936732695
# 1899
# empty queue
# ue-number sched1: 2
# 142.21218222800294
# 1901
# ue-number sched1: 0
# 41.64300650389533
# 1901
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 1
# 11.937116976415002
# 1923
# empty queue
# ue-number sched1: 1
# 142.26062420092248
# 1925
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 2
# 35.84851639019087
# 1945
# ue-number sched1: 0
# 32.44378001624356
# 1947
# empty queue
# ue-number sched1: 0
# 142.30817185316678
# 1949
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 41.43069845119262
# 1959
# ue-number sched1: 1
# 40.07029987415229
# 1959
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 2
# 22.815709502213956
# 1971
# empty queue
# ue-number sched1: 2
# 142.35485238566378
# 1973
# ue-number sched1: 1
# 40.5463049259278
# 1973
# empty queue
# empty queue
# empty queue
# ue-number sched1: 2
# 35.6750494785568
# 1979
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 1
# 40.39039792406697
# 1993
# empty queue
# ue-number sched1: 2
# 35.53623043422548
# 1995
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 41.23242519823556
# 2005
# ue-number sched1: 0
# 41.45687286646587
# 2005
# empty queue
# empty queue
# ue-number sched1: 1
# 13.86766265024839
# 2009
# empty queue
# ue-number sched1: 1
# 14.22172890785872
# 2011
# empty queue
# empty queue
# ue-number sched1: 2
# 35.80873607047304
# 2015
# empty queue
# ue-number sched1: 1
# 40.653596114443786
# 2017
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 2
# 36.39970823175915
# 2039
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 40.756390680578
# 2047
# ue-number sched1: 0
# 41.58345155469594
# 2047
# empty queue
# empty queue
# ue-number sched1: 1
# 40.22361790662846
# 2051
# empty queue
# ue-number sched1: 0
# 15.903748996883452
# 2053
# empty queue
# ue-number sched1: 0
# 12.426018994944643
# 2055
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 2
# 17.954974756247868
# 2063
# empty queue
# ue-number sched1: 2
# 142.52621731935457
# 2065
# ue-number sched1: 1
# 40.69672978952853
# 2065
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 1
# 40.40856676844737
# 2101
# empty queue
# ue-number sched1: 1
# 30.230651357989327
# 2103
# empty queue
# ue-number sched1: 1
# 142.59720742407492
# 2105
# ue-number sched1: 0
# 41.36798109842321
# 2107
# empty queue
# ue-number sched1: 2
# 35.23167812226879
# 2109
# empty queue
# ue-number sched1: 2
# 35.971028345801585
# 2111
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 1
# 40.584507035120566
# 2119
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 1
# 40.250746248179304
# 2149
# empty queue
# ue-number sched1: 2
# 10.243689387955808
# 2151
# empty queue
# ue-number sched1: 2
# 142.67977911390417
# 2153
# ue-number sched1: 2
# 36.08847638368751
# 2153
# empty queue
# empty queue
# ue-number sched1: 0
# 15.798090421040923
# 2157
# empty queue
# ue-number sched1: 0
# 18.555482211492684
# 2159
# ue-number sched1: 0
# 41.27904869697389
# 2159
# empty queue
# empty queue
# ue-number sched1: 1
# 40.683765117307495
# 2163
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 1
# 27.865796064600204
# 2193
# empty queue
# ue-number sched1: 1
# 12.540750205196765
# 2195
# empty queue
# ue-number sched1: 1
# 40.8918394599492
# 2197
# empty queue
# empty queue
# ue-number sched1: 2
# 35.55238278485928
# 2201
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 2
# 35.47641108099704
# 2215
# empty queue
# ue-number sched1: 0
# 41.11963175941179
# 2217
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 2
# 36.244878121186474
# 2225
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 1
# 40.94912999291944
# 2243
# empty queue
# ue-number sched1: 2
# 25.164526062426
# 2245
# empty queue
# ue-number sched1: 2
# 14.363373338309783
# 2247
# empty queue
# ue-number sched1: 2
# 25.15692013905857
# 2249
# empty queue
# ue-number sched1: 2
# 14.317326368324691
# 2251
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 40.91422106677074
# 2277
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 10.170554914742384
# 2283
# empty queue
# ue-number sched1: 0
# 142.8933232361654
# 2285
# ue-number sched1: 2
# 35.45878760775911
# 2285
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 1
# 27.79978089451186
# 2295
# ue-number sched1: 1
# 40.15222766316215
# 2295
# empty queue
# ue-number sched1: 1
# 142.91182127613075
# 2297
# empty queue
# ue-number sched1: 2
# 35.4255927136937
# 2299
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 1
# 40.745325927233004
# 2307
# empty queue
# empty queue
# ue-number sched1: 2
# 35.91411926591768
# 2311
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 40.94755577365661
# 2323
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 2
# 25.12122397590039
# 2341
# empty queue
# ue-number sched1: 2
# 11.948447622425352
# 2343
# empty queue
# ue-number sched1: 1
# 40.4263526854501
# 2345
# empty queue
# empty queue
# ue-number sched1: 1
# 10.21883749793798
# 2349
# empty queue
# ue-number sched1: 1
# 14.352822381864183
# 2351
# empty queue
# ue-number sched1: 2
# 36.16568217153698
# 2353
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 1
# 40.591952635717284
# 2365
# empty queue
# ue-number sched1: 0
# 41.03149668296505
# 2367
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 20.110028664273194
# 2383
# empty queue
# ue-number sched1: 0
# 143.04319314246797
# 2385
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 2
# 13.84519938348111
# 2399
# empty queue
# ue-number sched1: 2
# 143.06630218384055
# 2401
# empty queue
# ue-number sched1: 1
# 40.782475628692616
# 2403
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 2
# 35.57990045017665
# 2413
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 40.95916700208087
# 2421
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 2
# 35.519786221713275
# 2437
# empty queue
# empty queue
# empty queue
# ue-number sched1: 1
# 24.99229555514525
# 2443
# ue-number sched1: 1
# 40.93353369151748
# 2443
# empty queue
# ue-number sched1: 1
# 143.128681973835
# 2445
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 2
# 36.01234147177052
# 2461
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 41.00598343540374
# 2467
# empty queue
# empty queue
# empty queue
# ue-number sched1: 2
# 10.215729758595721
# 2473
# empty queue
# ue-number sched1: 2
# 12.740458371626598
# 2475
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 13.780453727328112
# 2481
# empty queue
# ue-number sched1: 0
# 12.063449204549363
# 2483
# empty queue
# empty queue
# empty queue
# ue-number sched1: 1
# 40.34565122072261
# 2491
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 1
# 40.62173551038139
# 2511
# empty queue
# empty queue
# empty queue
# ue-number sched1: 2
# 35.711868485081126
# 2517
# empty queue
# empty queue
# ue-number sched1: 0
# 40.796339392362434
# 2521
# ue-number sched1: 0
# 40.904611371976735
# 2521
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 1
# 15.742095204224867
# 2537
# empty queue
# ue-number sched1: 1
# 18.354153573864657
# 2539
# empty queue
# empty queue
# empty queue
# ue-number sched1: 1
# 40.15774035776963
# 2545
# empty queue
# ue-number sched1: 0
# 32.3625379055386
# 2547
# empty queue
# ue-number sched1: 0
# 143.26967059646952
# 2549
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 2
# 35.758396316791405
# 2557
# empty queue
# ue-number sched1: 1
# 40.344475481688015
# 2559
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 2
# 22.61392072215593
# 2571
# empty queue
# ue-number sched1: 2
# 143.30099017956053
# 2573
# empty queue
# empty queue
# ue-number sched1: 1
# 41.01719407355942
# 2577
# empty queue
# empty queue
# ue-number sched1: 0
# 40.62271216608671
# 2581
# ue-number sched1: 0
# 40.72853443955975
# 2581
# empty queue
# empty queue
# empty queue
# ue-number sched1: 2
# 36.11382073625257
# 2589
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 40.245986298173406
# 2635
# ue-number sched1: 0
# 40.65291381760484
# 2635
# empty queue
# empty queue
# ue-number sched1: 1
# 13.816229294427433
# 2639
# ue-number sched1: 1
# 40.92527129686566
# 2639
# empty queue
# ue-number sched1: 1
# 143.38740582929668
# 2641
# empty queue
# ue-number sched1: 0
# 10.157423363387892
# 2643
# empty queue
# ue-number sched1: 0
# 143.3923853894403
# 2645
# empty queue
# empty queue
# empty queue
# ue-number sched1: 2
# 36.03434507554878
# 2653
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 2
# 22.574208804478477
# 2665
# empty queue
# ue-number sched1: 2
# 14.4953224397441
# 2667
# empty queue
# empty queue
# ue-number sched1: 2
# 32.906015989061835
# 2671
# empty queue
# ue-number sched1: 2
# 143.42692970646772
# 2673
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 40.65576063704331
# 2685
# empty queue
# empty queue
# empty queue
# ue-number sched1: 1
# 40.84745683983493
# 2693
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 2
# 35.931779608884
# 2705
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 1
# 22.652736194158646
# 2719
# empty queue
# ue-number sched1: 1
# 143.484906995993
# 2721
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 40.67338456874223
# 2733
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 17.6496673973967
# 2747
# empty queue
# ue-number sched1: 0
# 143.5180256998308
# 2749
# ue-number sched1: 1
# 40.743040132086136
# 2749
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 2
# 22.45876355735518
# 2757
# empty queue
# ue-number sched1: 2
# 18.257257713432573
# 2759
# empty queue
# ue-number sched1: 2
# 35.809143106033815
# 2761
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 40.63194974362581
# 2785
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 1
# 24.880440752979712
# 2803
# ue-number sched1: 1
# 40.67178372550515
# 2803
# empty queue
# ue-number sched1: 1
# 143.58277358803664
# 2805
# ue-number sched1: 2
# 35.80134155372343
# 2805
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 40.63259286067848
# 2833
# ue-number sched1: 0
# 40.63501693661894
# 2833
# empty queue
# ue-number sched1: 0
# 20.20708024154594
# 2835
# empty queue
# ue-number sched1: 0
# 143.6189111129288
# 2837
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 2
# 35.63399019890507
# 2849
# empty queue
# ue-number sched1: 1
# 40.6676090278426
# 2851
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 2
# 24.961649928665185
# 2869
# empty queue
# ue-number sched1: 2
# 14.506778978778264
# 2871
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 2
# 35.40628646261774
# 2879
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 40.55356805158063
# 2889
# empty queue
# ue-number sched1: 2
# 35.857269421081654
# 2891
# empty queue
# ue-number sched1: 1
# 20.185793591404767
# 2893
# empty queue
# ue-number sched1: 1
# 12.984094424702294
# 2895
# ue-number sched1: 1
# 40.567545450022095
# 2895
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 11.88915971254316
# 2911
# empty queue
# ue-number sched1: 0
# 143.70234542878424
# 2913
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 1
# 40.936398738972855
# 2929
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 40.58569751947164
# 2935
# empty queue
# empty queue
# empty queue
# ue-number sched1: 2
# 35.86183974901587
# 2941
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 2
# 30.21549327655991
# 2955
# empty queue
# ue-number sched1: 2
# 143.74917666125958
# 2957
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 2
# 36.060986646211255
# 2983
# empty queue
# empty queue
# empty queue
# ue-number sched1: 1
# 32.83200585241602
# 2991
# ue-number sched1: 0
# 40.37336724334082
# 2991
# ue-number sched1: 0
# 40.49443933720798
# 2991
# empty queue
# ue-number sched1: 1
# 143.78672470134583
# 2993
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 1
# 40.234312134238515
# 3001
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 2
# 22.545372452086383
# 3013
# ue-number sched1: 1
# 40.49220594008325
# 3013
# empty queue
# ue-number sched1: 2
# 13.044222590767864
# 3015
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 32.789653212832
# 3025
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 2
# 36.15899123133526
# 3033
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 40.52617832288075
# 3039
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 1
# 40.30936554492106
# 3049
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 1
# 40.48427935590809
# 3063
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 1
# 24.977111962380732
# 3081
# empty queue
# ue-number sched1: 1
# 12.464479439954575
# 3083
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 1
# 40.21147254106033
# 3091
# ue-number sched1: 1
# 40.764623148455655
# 3091
# empty queue
# ue-number sched1: 2
# 36.13662176619679
# 3093
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 40.28554803249198
# 3099
# ue-number sched1: 0
# 40.37379083725723
# 3099
# empty queue
# ue-number sched1: 2
# 20.10411365628778
# 3101
# empty queue
# ue-number sched1: 2
# 12.475814876532644
# 3103
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 1
# 25.131451316332058
# 3131
# empty queue
# ue-number sched1: 1
# 143.9265572035939
# 3133
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 25.00903770461206
# 3141
# empty queue
# ue-number sched1: 0
# 12.498161765435134
# 3143
# empty queue
# ue-number sched1: 2
# 27.63338922570467
# 3145
# empty queue
# empty queue
# ue-number sched1: 1
# 40.649039556986644
# 3149
# empty queue
# empty queue
# ue-number sched1: 0
# 40.329343026774154
# 3153
# empty queue
# ue-number sched1: 2
# 35.996945807711064
# 3155
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 2
# 36.35162343352561
# 3181
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 1
# 40.186290529326115
# 3189
# empty queue
# ue-number sched1: 1
# 40.753452456455754
# 3191
# empty queue
# empty queue
# ue-number sched1: 0
# 13.837266716687042
# 3195
# ue-number sched1: 0
# 40.42508711145511
# 3195
# empty queue
# ue-number sched1: 0
# 143.98740802027473
# 3197
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 1
# 18.035314410161597
# 3211
# empty queue
# ue-number sched1: 1
# 144.0023367102125
# 3213
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 2
# 25.23519240179768
# 3227
# empty queue
# ue-number sched1: 2
# 144.0171546080836
# 3229
# empty queue
# ue-number sched1: 2
# 36.20513630907046
# 3231
# empty queue
# ue-number sched1: 1
# 40.84256167932521
# 3233
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 40.39354155248673
# 3247
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 2
# 36.19191762843658
# 3267
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 33.08123489964145
# 3273
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 1
# 33.1019068561902
# 3281
# empty queue
# empty queue
# empty queue
# ue-number sched1: 1
# 40.69166252882649
# 3287
# empty queue
# ue-number sched1: 1
# 40.75530142741913
# 3289
# empty queue
# ue-number sched1: 2
# 36.18142382357543
# 3291
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 40.29231815100308
# 3297
# ue-number sched1: 0
# 40.375259516441055
# 3297
# empty queue
# empty queue
# ue-number sched1: 2
# 10.261324203410078
# 3301
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 2
# 36.58622579970616
# 3311
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 1
# 40.78072326213558
# 3335
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 40.41574636548904
# 3343
# ue-number sched1: 0
# 40.417865496100625
# 3343
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 2
# 36.59938352435531
# 3359
# empty queue
# ue-number sched1: 1
# 27.924743859013812
# 3361
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 30.556487063907802
# 3377
# empty queue
# empty queue
# ue-number sched1: 2
# 20.397961389600706
# 3381
# ue-number sched1: 1
# 40.56321424610908
# 3381
# ue-number sched1: 1
# 40.81741027857103
# 3381
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 40.40953617560038
# 3393
# ue-number sched1: 0
# 40.41162590852829
# 3393
# empty queue
# empty queue
# empty queue
# ue-number sched1: 2
# 36.6398779537165
# 3399
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 2
# 36.50464144857
# 3431
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 1
# 40.687015406751286
# 3441
# empty queue
# ue-number sched1: 0
# 40.40573341306379
# 3443
# empty queue
# empty queue
# empty queue
# ue-number sched1: 1
# 18.19387169929852
# 3449
# empty queue
# ue-number sched1: 2
# 36.80420717724989
# 3451
# empty queue
# empty queue
# ue-number sched1: 2
# 25.478400074391534
# 3455
# empty queue
# ue-number sched1: 2
# 144.21703108377932
# 3457
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 13.977762225250665
# 3473
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 2
# 36.930062768804206
# 3487
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 40.37689291209633
# 3495
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 1
# 40.12639835077406
# 3515
# ue-number sched1: 1
# 40.39947761155621
# 3515
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 2
# 23.03238008839724
# 3523
# empty queue
# ue-number sched1: 2
# 144.27286553758645
# 3525
# empty queue
# empty queue
# ue-number sched1: 2
# 36.83562170307635
# 3529
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 1
# 14.014158478034798
# 3537
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 2
# 36.60315275151526
# 3555
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 40.20141945599742
# 3561
# empty queue
# ue-number sched1: 2
# 36.96891639746028
# 3563
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 20.57528498916966
# 3569
# empty queue
# empty queue
# ue-number sched1: 1
# 40.06276143335057
# 3573
# ue-number sched1: 1
# 40.303437962476416
# 3573
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 2
# 20.645103669987517
# 3595
# empty queue
# ue-number sched1: 2
# 144.33025453365948
# 3597
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 40.28782132642279
# 3603
# ue-number sched1: 2
# 36.650297817183244
# 3603
# empty queue
# ue-number sched1: 2
# 37.20232535400568
# 3605
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 1
# 23.103979236148355
# 3615
# empty queue
# ue-number sched1: 1
# 144.34589181005302
# 3617
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 1
# 40.01770010614273
# 3627
# ue-number sched1: 1
# 40.254805785738505
# 3627
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 40.30587654329954
# 3651
# empty queue
# ue-number sched1: 2
# 37.28842795470652
# 3653
# empty queue
# empty queue
# empty queue
# ue-number sched1: 2
# 33.73659591655872
# 3659
# empty queue
# ue-number sched1: 2
# 144.37984281386366
# 3661
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 30.93450777647572
# 3669
# empty queue
# ue-number sched1: 1
# 40.32803188504471
# 3671
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 1
# 10.44140249167939
# 3693
# empty queue
# ue-number sched1: 2
# 37.38750723737657
# 3695
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 40.288836219462894
# 3701
# ue-number sched1: 0
# 40.29078465604234
# 3701
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 1
# 40.081680718809345
# 3721
# ue-number sched1: 1
# 40.31277943401525
# 3721
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 2
# 28.308568229648248
# 3729
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 2
# 37.1173501264404
# 3741
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 40.263446931752924
# 3753
# ue-number sched1: 0
# 40.26537513667385
# 3753
# empty queue
# empty queue
# ue-number sched1: 2
# 37.13812290250514
# 3757
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 23.16404965325838
# 3769
# ue-number sched1: 2
# 37.567219083982856
# 3769
# empty queue
# empty queue
# ue-number sched1: 1
# 39.79430105201988
# 3773
# ue-number sched1: 1
# 40.28733198203525
# 3773
# empty queue
# ue-number sched1: 1
# 28.4263203287229
# 3775
# empty queue
# ue-number sched1: 1
# 144.4664958886496
# 3777
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 40.27240707058622
# 3803
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 2
# 37.55233818006633
# 3813
# empty queue
# empty queue
# ue-number sched1: 2
# 28.37565625353314
# 3817
# empty queue
# empty queue
# ue-number sched1: 1
# 39.97758613355286
# 3821
# empty queue
# ue-number sched1: 1
# 40.29409735873372
# 3823
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 1
# 23.30495041435261
# 3847
# empty queue
# ue-number sched1: 1
# 144.5183039283007
# 3849
# ue-number sched1: 0
# 40.310658174297906
# 3849
# empty queue
# empty queue
# ue-number sched1: 2
# 37.69666763714264
# 3853
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 1
# 40.03991176738963
# 3865
# empty queue
# ue-number sched1: 1
# 40.352805506265405
# 3867
# empty queue
# ue-number sched1: 0
# 16.26412459179277
# 3869
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 2
# 23.332524378389106
# 3895
# empty queue
# ue-number sched1: 2
# 144.55204405260844
# 3897
# ue-number sched1: 0
# 40.24678597081632
# 3897
# ue-number sched1: 0
# 40.31696898699009
# 3897
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 2
# 37.636730521805404
# 3907
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 1
# 23.30031725360903
# 3917
# empty queue
# empty queue
# empty queue
# ue-number sched1: 1
# 40.286518157314276
# 3923
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 40.39295261559382
# 3939
# ue-number sched1: 0
# 40.394756892665264
# 3939
# empty queue
# ue-number sched1: 2
# 37.835379783679535
# 3941
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 2
# 25.947327810368403
# 3967
# empty queue
# ue-number sched1: 2
# 144.60150477507935
# 3969
# empty queue
# ue-number sched1: 0
# 20.90086784460488
# 3971
# empty queue
# ue-number sched1: 0
# 144.60421320097146
# 3973
# empty queue
# empty queue
# ue-number sched1: 1
# 39.978309551467234
# 3977
# ue-number sched1: 1
# 40.23227527700119
# 3977
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 2
# 37.62117044356313
# 3989
# empty queue
# empty queue
# ue-number sched1: 0
# 40.34941661483668
# 3993
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 2
# 37.68388125967723
# 4007
# empty queue
# ue-number sched1: 1
# 25.91548618680668
# 4009
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 2
# 37.988934001568
# 4029
# empty queue
# empty queue
# empty queue
# ue-number sched1: 2
# 34.1329486294864
# 4035
# ue-number sched1: 1
# 40.14970208941388
# 4035
# empty queue
# ue-number sched1: 2
# 144.64700039838095
# 4037
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 40.283477607033014
# 4049
# ue-number sched1: 0
# 40.28525990448744
# 4049
# empty queue
# ue-number sched1: 0
# 20.96502501466931
# 4051
# empty queue
# ue-number sched1: 0
# 144.65753891539032
# 4053
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 2
# 37.96410074104111
# 4077
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 1
# 10.600113782952903
# 4091
# empty queue
# ue-number sched1: 1
# 144.6836149830125
# 4093
# empty queue
# ue-number sched1: 1
# 39.59558320665127
# 4095
# ue-number sched1: 1
# 40.04989441954341
# 4095
# empty queue
# ue-number sched1: 2
# 126.39185072013962
# 4097
# empty queue
# ue-number sched1: 2
# 126.40980830718031
# 4099
# empty queue
# ue-number sched1: 2
# 126.42775275772722
# 4101
# empty queue
# ue-number sched1: 2
# 126.44568408778869
# 4103
# empty queue
# ue-number sched1: 2
# 126.46360231334587
# 4105
# empty queue
# ue-number sched1: 2
# 12.384208389771606
# 4107
# ue-number sched1: 0
# 40.20338490683443
# 4107
# empty queue
# ue-number sched1: 2
# 144.69393889765774
# 4109
# empty queue
# ue-number sched1: 2
# 38.16098168626353
# 4111
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 20.982260114881853
# 4133
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 1
# 39.707343441566444
# 4153
# empty queue
# ue-number sched1: 1
# 39.96252819645415
# 4155
# empty queue
# empty queue
# ue-number sched1: 0
# 40.19121506957595
# 4159
# empty queue
# ue-number sched1: 2
# 38.055761833717376
# 4161
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 1
# 23.511258613044124
# 4171
# empty queue
# ue-number sched1: 1
# 144.73464050952686
# 4173
# empty queue
# empty queue
# ue-number sched1: 2
# 28.692245596956717
# 4177
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 1
# 39.90825062267901
# 4201
# empty queue
# ue-number sched1: 1
# 39.98202929252849
# 4203
# ue-number sched1: 2
# 37.72445862964075
# 4203
# empty queue
# ue-number sched1: 2
# 37.92625223419198
# 4205
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 40.16979700856884
# 4211
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 2
# 38.25291148502269
# 4223
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 34.33195848634902
# 4231
# empty queue
# ue-number sched1: 0
# 144.77195886871908
# 4233
# empty queue
# empty queue
# empty queue
# ue-number sched1: 1
# 16.48660106565861
# 4239
# empty queue
# ue-number sched1: 1
# 144.77687486645272
# 4241
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 1
# 39.607967189908194
# 4249
# ue-number sched1: 1
# 40.01050708936927
# 4249
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 40.22439657147385
# 4255
# empty queue
# empty queue
# ue-number sched1: 2
# 28.831489524663166
# 4259
# empty queue
# ue-number sched1: 2
# 144.78910437749096
# 4261
# empty queue
# empty queue
# ue-number sched1: 1
# 127.00410061697485
# 4265
# ue-number sched1: 2
# 38.36863623704058
# 4265
# empty queue
# ue-number sched1: 1
# 127.02120769440232
# 4267
# empty queue
# ue-number sched1: 1
# 127.03830274999042
# 4269
# empty queue
# ue-number sched1: 1
# 127.05538579781295
# 4271
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 1
# 39.6699645242607
# 4289
# ue-number sched1: 1
# 40.10370899511072
# 4289
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 40.306116479427935
# 4295
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 1
# 10.660665837418367
# 4309
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 28.90011868232708
# 4315
# empty queue
# ue-number sched1: 0
# 144.8228947903027
# 4317
# empty queue
# ue-number sched1: 2
# 38.053339003954285
# 4319
# empty queue
# ue-number sched1: 2
# 34.34113233720649
# 4321
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 2
# 38.406272624130644
# 4333
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 40.34896845865676
# 4341
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 1
# 39.9826845678987
# 4353
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 2
# 3.800761572991701
# 4379
# ue-number sched1: 2
# 38.127559032497075
# 4379
# empty queue
# ue-number sched1: 2
# 127.37953772772393
# 4381
# empty queue
# ue-number sched1: 2
# 127.3961063935401
# 4383
# empty queue
# ue-number sched1: 0
# 40.40015269130205
# 4385
# ue-number sched1: 2
# 127.41266372389504
# 4385
# empty queue
# empty queue
# empty queue
# ue-number sched1: 1
# 10.693249849311291
# 4391
# ue-number sched1: 2
# 38.21377024296927
# 4391
# empty queue
# ue-number sched1: 1
# 144.86771804797033
# 4393
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 16.567699777528002
# 4399
# empty queue
# ue-number sched1: 0
# 144.87236878354778
# 4401
# empty queue
# empty queue
# ue-number sched1: 2
# 34.41915779423936
# 4405
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 1
# 39.701997503604936
# 4413
# empty queue
# ue-number sched1: 1
# 39.87420543169019
# 4415
# ue-number sched1: 2
# 38.25335475072026
# 4415
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 40.35918533637137
# 4439
# ue-number sched1: 2
# 38.22628019080736
# 4439
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 2
# 38.28449404733173
# 4451
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 2
# 38.58294981730582
# 4471
# empty queue
# ue-number sched1: 1
# 21.17353555257614
# 4473
# empty queue
# ue-number sched1: 1
# 39.55180995479129
# 4475
# ue-number sched1: 1
# 39.777608433013675
# 4475
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 10.73179172524551
# 4483
# empty queue
# ue-number sched1: 0
# 144.92044949764272
# 4485
# empty queue
# ue-number sched1: 2
# 12.524608688566401
# 4487
# empty queue
# ue-number sched1: 2
# 144.92270541280323
# 4489
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 40.26542664299539
# 4499
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 2
# 38.40309134904674
# 4517
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 1
# 39.75366459291808
# 4529
# empty queue
# empty queue
# empty queue
# ue-number sched1: 2
# 38.70527822025338
# 4535
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 1
# 18.855328028115675
# 4557
# empty queue
# ue-number sched1: 2
# 18.885298311989892
# 4559
# ue-number sched1: 0
# 40.174136737827894
# 4559
# empty queue
# ue-number sched1: 2
# 144.96280419916528
# 4561
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 16.622449058077283
# 4571
# empty queue
# ue-number sched1: 0
# 144.96939530849437
# 4573
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 2
# 38.741253603473815
# 4585
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 1
# 39.55768403745529
# 4601
# empty queue
# empty queue
# ue-number sched1: 1
# 2.7347950077716097
# 4605
# empty queue
# ue-number sched1: 1
# 128.04034044829206
# 4607
# empty queue
# ue-number sched1: 1
# 128.0559533056476
# 4609
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 40.119966530488185
# 4615
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 2
# 34.67573432464688
# 4627
# empty queue
# ue-number sched1: 2
# 144.99981494756105
# 4629
# empty queue
# empty queue
# ue-number sched1: 2
# 38.756928223741355
# 4633
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 1
# 26.377093273691916
# 4645
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 21.30765648216443
# 4655
# ue-number sched1: 1
# 39.3113299565758
# 4655
# ue-number sched1: 1
# 39.528448897508866
# 4655
# empty queue
# ue-number sched1: 0
# 145.0148190599602
# 4657
# empty queue
# ue-number sched1: 0
# 40.1703060760556
# 4659
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 2
# 38.69626150929766
# 4675
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 2
# 10.775166988968486
# 4693
# empty queue
# empty queue
# empty queue
# ue-number sched1: 2
# 38.945546153645985
# 4699
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 40.202605644069926
# 4705
# ue-number sched1: 2
# 3.101554425550197
# 4705
# ue-number sched1: 1
# 39.19344094628799
# 4705
# empty queue
# ue-number sched1: 1
# 39.38694138373301
# 4707
# ue-number sched1: 2
# 128.29623590273772
# 4707
# ue-number sched1: 1
# 39.51666584912844
# 4707
# empty queue
# ue-number sched1: 2
# 128.31146286474603
# 4709
# empty queue
# ue-number sched1: 2
# 128.32668013011119
# 4711
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 1
# 26.471815900622282
# 4731
# empty queue
# ue-number sched1: 1
# 145.05487271763604
# 4733
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 16.696017224635774
# 4743
# ue-number sched1: 1
# 39.39370043244569
# 4743
# ue-number sched1: 1
# 39.63839920949978
# 4743
# empty queue
# ue-number sched1: 0
# 145.06110905467673
# 4745
# empty queue
# empty queue
# ue-number sched1: 0
# 40.25122620254135
# 4749
# empty queue
# ue-number sched1: 2
# 38.828738056588755
# 4751
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 2
# 26.459404554033405
# 4773
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 2
# 38.897059359421846
# 4789
# empty queue
# ue-number sched1: 0
# 40.31577890461994
# 4791
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 1
# 39.23248633262198
# 4801
# empty queue
# ue-number sched1: 1
# 34.81313670606835
# 4803
# ue-number sched1: 1
# 39.39088056823876
# 4803
# ue-number sched1: 1
# 39.55965198598428
# 4803
# empty queue
# ue-number sched1: 1
# 145.09194028633937
# 4805
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 32.007665384306144
# 4831
# ue-number sched1: 2
# 38.60232832113044
# 4831
# empty queue
# ue-number sched1: 0
# 145.10613175297485
# 4833
# empty queue
# ue-number sched1: 2
# 38.76149579005196
# 4835
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 1
# 39.35461757355488
# 4843
# ue-number sched1: 1
# 39.64589268865429
# 4843
# empty queue
# ue-number sched1: 0
# 40.279189260866815
# 4845
# empty queue
# empty queue
# ue-number sched1: 2
# 39.074680675089596
# 4849
# empty queue
# empty queue
# ue-number sched1: 2
# 23.917497173555187
# 4853
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 1
# 18.995196876573907
# 4877
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 1
# 39.65757402052449
# 4893
# empty queue
# empty queue
# ue-number sched1: 0
# 40.259844399416004
# 4897
# ue-number sched1: 2
# 38.8625725367908
# 4897
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 10.826625516197348
# 4909
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 2
# 38.727566617235695
# 4925
# empty queue
# empty queue
# ue-number sched1: 2
# 39.12219137838383
# 4929
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 2
# 34.86301924061294
# 4937
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 40.263854913647265
# 4945
# ue-number sched1: 0
# 40.26531823924613
# 4945
# empty queue
# ue-number sched1: 1
# 39.34810360006174
# 4947
# empty queue
# ue-number sched1: 1
# 39.61293526229652
# 4949
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 1
# 4.29332041200223
# 4959
# empty queue
# ue-number sched1: 1
# 29.281746246369877
# 4961
# ue-number sched1: 1
# 128.93068369963177
# 4961
# empty queue
# ue-number sched1: 1
# 128.94500352963385
# 4963
# empty queue
# ue-number sched1: 1
# 128.95931470717068
# 4965
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 2
# 39.166861554846456
# 4977
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 40.27068478592089
# 4995
# ue-number sched1: 1
# 39.43828511269162
# 4995
# ue-number sched1: 1
# 39.640599770326716
# 4995
# empty queue

# %%
env=simpy.Environment()
#env = simpy.rt.RealtimeEnvironment(factor=1/10)

ue_list=np.array([])
ue_list2=np.array([])
#define UEs

    
max_prb=50
thr=6
cluster=[19,20]


x=np.append(np.ones(70)*19,np.ones(70)*20)
y=np.append(np.ones(70)*20,np.ones(70)*19)
sinr=np.random.randint(0,12,70*2)
sinr2=np.random.randint(2,16,70*2)
rt_nrt=np.array([])
rt_nrt=np.append(rt_nrt,np.ones(140))

df=pd.DataFrame()
df['PCI Serving']=x
df['PCI Coord']=y
df['JT_1 SINR [lin]']=sinr
df['JT_2 SINR [lin]']=sinr2
df['usage']=rt_nrt
df['id']=np.arange(0,140)
   
df['PCI Serving']=df['PCI Serving'].astype('int')
df['PCI Coord']=df['PCI Coord'].astype('int')

df['JT_1 SINR [lin]']=df['JT_1 SINR [lin]'].astype('int')
df['JT_2 SINR [lin]']=df['JT_2 SINR [lin]'].astype('int')


ue_dict=df_to_ue_lists(df,[19,20],6)
ue_all=np.array([])
for i in cluster:
    ue_all=np.append(ue_all,ue_dict[i])

prb_number_comp=calculate_prb_number(ue_all,max_prb)
prb_number_normal=max_prb-prb_number_comp

#Start processes
    
for i in cluster:
    ue_list=ue_dict[i]
    for j in np.arange(0,70):
        env.process(ue_list[j].rt_user(env))

        
ue_comp=np.array([]) #ues that use comp -> processed be central_scheduler
for i in cluster:
    ue_list=ue_dict[i]
    new_ue_list=np.array([])
    for j in ue_list:
        if(j.comp == 0):
            new_ue_list=np.append(new_ue_list,j)
        else:
            ue_comp=np.append(ue_comp,j)
    ue_dict[i]=new_ue_list #user without comp
    
env.process(central_scheduler(env,ue_comp,SCHEDULE_T,[19,20],prb_number_comp))

counter=0
for i in cluster:
    ue_list=ue_dict[i]
    ue_19=ue_all[counter*70:((counter+1)*70-1)]
    env.process(scheduler(env,ue_list,SCHEDULE_T,[19,20],prb_number_normal,ue_19,50,1))
env.run(until=5000)
# Out:
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 160.0
# 1
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 2
# 5.517241379310345
# 29
# empty queue
# ue-number sched1: 2
# 5.517241379310345
# 29
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 2
# 7.524726323661449
# 49
# empty queue
# ue-number sched1: 2
# 6.506416817511704
# 49
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 1
# 2.6229508196721314
# 61
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 2
# 8.669317800822544
# 69
# empty queue
# ue-number sched1: 2
# 6.925207450361228
# 69
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# <ipython-input-59-431104769901>:119: RuntimeWarning: divide by zero encountered in double_scalars
#   metric=np.append(metric, (alpha*i.queue2.level*(cp**e1/(i.mR2)**e2)))  #list the metric of all UEs in the process
# <ipython-input-59-431104769901>:119: RuntimeWarning: invalid value encountered in double_scalars
#   metric=np.append(metric, (alpha*i.queue2.level*(cp**e1/(i.mR2)**e2)))  #list the metric of all UEs in the process
# <ipython-input-59-431104769901>:96: RuntimeWarning: divide by zero encountered in double_scalars
#   metric=np.append(metric, (alpha*i.queue.level*((i.cp)**e1/(i.mR)**e2)))  #list the metric of all UEs in the process
# <ipython-input-59-431104769901>:96: RuntimeWarning: invalid value encountered in double_scalars
#   metric=np.append(metric, (alpha*i.queue.level*((i.cp)**e1/(i.mR)**e2)))  #list the metric of all UEs in the process
# ue-number sched1: 1
# 4.253824158318857
# 81
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 2
# 9.437307401246585
# 89
# empty queue
# ue-number sched1: 2
# 7.15776989582437
# 89
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 1
# 5.395929122224509
# 101
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 2
# 9.999945652709059
# 109
# empty queue
# ue-number sched1: 2
# 7.306161661988649
# 109
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 1.415929203539823
# 113
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 6.664192343591928
# 115
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 1
# 6.254187388768983
# 121
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 6.0091365715292495
# 125
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 2
# 10.435706573092492
# 129
# empty queue
# ue-number sched1: 2
# 7.40926954634827
# 129
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 2.508575291120081
# 133
# empty queue
# ue-number sched1: 0
# 2.4052016178635025
# 133
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 7.337937380977863
# 135
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 1
# 6.930123417350031
# 141
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 2
# 10.786448939615223
# 149
# empty queue
# ue-number sched1: 2
# 7.485177050731128
# 149
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 3.385202638877759
# 153
# empty queue
# ue-number sched1: 0
# 3.1355060338883174
# 153
# empty queue
# ue-number sched1: 0
# 10.29203474960291
# 153
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 7.882072526117597
# 155
# empty queue
# empty queue
# ue-number sched1: 0
# 10.06641798008404
# 155
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 12.991033990564473
# 157
# empty queue
# empty queue
# ue-number sched1: 0
# 6.046927087948019
# 157
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 9.65099518773917
# 159
# empty queue
# empty queue
# ue-number sched1: 0
# 12.239210981173102
# 161
# empty queue
# empty queue
# ue-number sched1: 1
# 7.480629633350683
# 161
# ue-number sched1: 0
# 28.01868843388222
# 161
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 9.276004580194522
# 163
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 16.177973762511368
# 167
# empty queue
# empty queue
# ue-number sched1: 2
# 0.9580838323353293
# 167
# empty queue
# empty queue
# ue-number sched1: 2
# 11.076863619684326
# 169
# empty queue
# ue-number sched1: 2
# 7.543449249185809
# 169
# empty queue
# ue-number sched1: 0
# 0.9467455621301775
# 169
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 4.108975086046228
# 173
# empty queue
# ue-number sched1: 0
# 3.6968148301474963
# 173
# empty queue
# ue-number sched1: 0
# 10.605537273670391
# 173
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 8.333660404692093
# 175
# empty queue
# empty queue
# ue-number sched1: 0
# 10.389779188496988
# 175
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 13.141239168000443
# 177
# empty queue
# empty queue
# ue-number sched1: 0
# 6.600034603749503
# 177
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 9.991320741129405
# 179
# empty queue
# empty queue
# ue-number sched1: 0
# 12.429181248365362
# 181
# empty queue
# empty queue
# ue-number sched1: 1
# 7.94042871421683
# 181
# ue-number sched1: 0
# 27.313905124274385
# 181
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 9.630241435250419
# 183
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 2
# 1.761160889863601
# 187
# empty queue
# empty queue
# ue-number sched1: 2
# 11.32260310553619
# 189
# empty queue
# ue-number sched1: 2
# 7.589626231436772
# 189
# empty queue
# ue-number sched1: 0
# 1.7419538799956809
# 189
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 4.719851670551814
# 193
# empty queue
# ue-number sched1: 0
# 4.1417374922538395
# 193
# empty queue
# ue-number sched1: 0
# 10.871521692491907
# 193
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 1
# 0.8205128205128205
# 195
# empty queue
# ue-number sched1: 0
# 10.664514254957153
# 195
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 13.270291381585306
# 197
# empty queue
# empty queue
# ue-number sched1: 0
# 7.069122978882337
# 197
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 10.281302850744611
# 199
# empty queue
# empty queue
# ue-number sched1: 0
# 12.592256265048075
# 201
# empty queue
# empty queue
# ue-number sched1: 1
# 8.332089419242745
# 201
# ue-number sched1: 0
# 26.718988955858595
# 201
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 9.932955055249693
# 203
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 8.096913892365595
# 205
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 2
# 4.352320414570443
# 207
# empty queue
# empty queue
# ue-number sched1: 2
# 11.534144528308973
# 209
# empty queue
# ue-number sched1: 2
# 7.627141543481626
# 209
# empty queue
# ue-number sched1: 0
# 2.422271262581172
# 209
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 5.244521396401043
# 213
# empty queue
# ue-number sched1: 0
# 4.503093803022558
# 213
# empty queue
# ue-number sched1: 0
# 11.100974987875482
# 213
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 1
# 1.4881928639456787
# 215
# empty queue
# ue-number sched1: 0
# 10.901782346850306
# 215
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 13.382783351974265
# 217
# empty queue
# empty queue
# ue-number sched1: 0
# 4.123691713015262
# 217
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 10.532317361358286
# 219
# empty queue
# empty queue
# ue-number sched1: 0
# 12.734294983236989
# 221
# empty queue
# empty queue
# ue-number sched1: 1
# 8.671009061631324
# 221
# ue-number sched1: 0
# 26.208169631450666
# 221
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 6.021971915524455
# 223
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 8.440626562821423
# 225
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 2
# 4.861456180518013
# 227
# empty queue
# empty queue
# ue-number sched1: 2
# 11.718805824800812
# 229
# empty queue
# ue-number sched1: 2
# 7.658237945580703
# 229
# empty queue
# ue-number sched1: 0
# 3.013010703136377
# 229
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 5.701585799592033
# 233
# empty queue
# ue-number sched1: 0
# 4.8024205468811365
# 233
# empty queue
# ue-number sched1: 0
# 11.30161512171522
# 233
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 1
# 2.042117351467047
# 235
# empty queue
# ue-number sched1: 0
# 11.109445630865434
# 235
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 13.482015665008218
# 237
# empty queue
# empty queue
# ue-number sched1: 0
# 4.621351044821341
# 237
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 10.752427353230622
# 239
# empty queue
# empty queue
# ue-number sched1: 0
# 12.859503778949538
# 241
# empty queue
# empty queue
# ue-number sched1: 1
# 8.968104724686437
# 241
# ue-number sched1: 0
# 25.763400791099482
# 241
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 6.4278022339416125
# 243
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 8.742572684433936
# 245
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 2
# 5.308670816459463
# 247
# empty queue
# empty queue
# ue-number sched1: 2
# 11.881876594197635
# 249
# empty queue
# ue-number sched1: 2
# 7.6844432345702955
# 249
# empty queue
# ue-number sched1: 0
# 3.5322973338119024
# 249
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 6.104462871194527
# 253
# empty queue
# ue-number sched1: 0
# 5.054437200613104
# 253
# empty queue
# ue-number sched1: 0
# 11.479046650460726
# 253
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 1
# 2.5090856594660527
# 255
# empty queue
# ue-number sched1: 0
# 11.29322714011087
# 255
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 13.570430915311006
# 257
# empty queue
# empty queue
# ue-number sched1: 0
# 5.060822792614841
# 257
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 10.94753093126741
# 259
# empty queue
# empty queue
# ue-number sched1: 0
# 12.970992927825877
# 261
# empty queue
# empty queue
# ue-number sched1: 1
# 9.231363588190847
# 261
# ue-number sched1: 0
# 25.371620874065332
# 261
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 6.787415539892622
# 263
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 9.010613982116359
# 265
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 2
# 6.653551836250649
# 267
# empty queue
# empty queue
# ue-number sched1: 2
# 12.027289746093912
# 269
# empty queue
# ue-number sched1: 2
# 7.7068345728489085
# 269
# empty queue
# ue-number sched1: 0
# 3.9934984700283955
# 269
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 6.463109570917688
# 273
# empty queue
# ue-number sched1: 0
# 5.269546023550308
# 273
# empty queue
# ue-number sched1: 0
# 11.637452558772061
# 273
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 1
# 2.9080906088693057
# 275
# empty queue
# ue-number sched1: 0
# 11.457406811508207
# 275
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 13.64988157712042
# 277
# empty queue
# empty queue
# ue-number sched1: 0
# 5.452658753015823
# 277
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 11.122056960718483
# 279
# empty queue
# empty queue
# ue-number sched1: 0
# 13.071119512239731
# 281
# empty queue
# empty queue
# ue-number sched1: 1
# 9.466783593192941
# 281
# ue-number sched1: 0
# 25.023113858751202
# 281
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 7.108994018317819
# 283
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 9.250680532620216
# 285
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 2
# 6.975444761759208
# 287
# empty queue
# empty queue
# ue-number sched1: 2
# 12.158039464184842
# 289
# empty queue
# ue-number sched1: 2
# 7.726193502816095
# 289
# empty queue
# ue-number sched1: 0
# 4.406718956183203
# 289
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 6.7850922292781135
# 293
# empty queue
# ue-number sched1: 0
# 5.455306995215555
# 293
# empty queue
# ue-number sched1: 0
# 11.780027601437862
# 293
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 1
# 3.2529683002335754
# 295
# empty queue
# ue-number sched1: 0
# 11.605258938295528
# 295
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 13.721802071939797
# 297
# empty queue
# empty queue
# ue-number sched1: 0
# 5.804908710954751
# 297
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 11.279405341355524
# 299
# empty queue
# empty queue
# ue-number sched1: 0
# 13.161707460203429
# 301
# empty queue
# empty queue
# ue-number sched1: 1
# 9.678969134519514
# 301
# ue-number sched1: 0
# 24.710483632531265
# 301
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 5.661884728596588
# 303
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 9.467341899851652
# 305
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 2
# 7.2659607327315765
# 307
# empty queue
# empty queue
# ue-number sched1: 2
# 12.276451598774823
# 309
# empty queue
# ue-number sched1: 2
# 7.743101024194554
# 309
# empty queue
# ue-number sched1: 0
# 4.779759178129152
# 309
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 7.076278009340028
# 313
# empty queue
# ue-number sched1: 0
# 5.617346683092279
# 313
# empty queue
# ue-number sched1: 0
# 11.909260174946544
# 313
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 1
# 3.5540371576915017
# 315
# empty queue
# ue-number sched1: 0
# 11.739337522965844
# 315
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 13.78732311454262
# 317
# empty queue
# empty queue
# ue-number sched1: 0
# 6.123835625146805
# 317
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 11.422235862005792
# 319
# empty queue
# empty queue
# ue-number sched1: 0
# 13.244193643701696
# 321
# empty queue
# empty queue
# ue-number sched1: 1
# 9.871522081662315
# 321
# ue-number sched1: 0
# 24.4279879257827
# 321
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 5.979429499038343
# 323
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 9.664184372430675
# 325
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 2
# 7.529901776255539
# 327
# empty queue
# empty queue
# ue-number sched1: 2
# 12.384364430418406
# 329
# empty queue
# ue-number sched1: 2
# 7.757998154274784
# 329
# empty queue
# ue-number sched1: 0
# 5.118750064717702
# 329
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 7.341296486114816
# 333
# empty queue
# ue-number sched1: 0
# 5.759939283283196
# 333
# empty queue
# ue-number sched1: 0
# 12.027121626530828
# 333
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 1
# 3.819149143562134
# 335
# empty queue
# ue-number sched1: 0
# 11.86166838667901
# 335
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 13.847349940323975
# 337
# empty queue
# empty queue
# ue-number sched1: 0
# 6.414395686330827
# 337
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 11.552663625479479
# 339
# empty queue
# empty queue
# ue-number sched1: 0
# 13.319727754350422
# 341
# empty queue
# empty queue
# ue-number sched1: 1
# 10.047306421141109
# 341
# ue-number sched1: 0
# 24.171091820401408
# 341
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 6.269218168494429
# 343
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 9.844067641041516
# 345
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 2
# 7.771098637608961
# 347
# empty queue
# empty queue
# ue-number sched1: 2
# 12.48325296533961
# 349
# empty queue
# ue-number sched1: 2
# 7.771225767572236
# 349
# empty queue
# ue-number sched1: 0
# 5.428586423256927
# 349
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 7.583856574257033
# 353
# empty queue
# ue-number sched1: 0
# 5.886389976045495
# 353
# empty queue
# ue-number sched1: 0
# 12.135196941855863
# 353
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 1
# 4.05438523816196
# 355
# empty queue
# ue-number sched1: 0
# 11.973882065327864
# 355
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 13.902617185510774
# 357
# empty queue
# empty queue
# ue-number sched1: 0
# 6.68056950436853
# 357
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 11.67239481248075
# 359
# empty queue
# empty queue
# ue-number sched1: 0
# 13.38924232501322
# 361
# empty queue
# empty queue
# ue-number sched1: 1
# 10.208632153776978
# 361
# ue-number sched1: 0
# 23.936160159221576
# 361
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 6.5350817636717755
# 363
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 10.009303986580061
# 365
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 2
# 7.9926498480458275
# 367
# empty queue
# empty queue
# ue-number sched1: 2
# 12.574316515466196
# 369
# empty queue
# ue-number sched1: 2
# 7.783051546183914
# 369
# empty queue
# ue-number sched1: 0
# 5.713230206710143
# 369
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 7.806969522597623
# 373
# empty queue
# ue-number sched1: 0
# 5.999294858941302
# 373
# empty queue
# ue-number sched1: 0
# 12.234777145811465
# 373
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 1
# 4.2645281381594256
# 375
# empty queue
# ue-number sched1: 0
# 12.077307941211071
# 375
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 13.953728243954778
# 377
# empty queue
# empty queue
# ue-number sched1: 0
# 6.925596103083641
# 377
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 11.782823200414143
# 379
# empty queue
# empty queue
# ue-number sched1: 0
# 13.453502915569267
# 381
# empty queue
# empty queue
# ue-number sched1: 1
# 10.357386055855944
# 381
# ue-number sched1: 0
# 23.720240543403577
# 381
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 6.780148716584023
# 383
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 10.161786209152345
# 385
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 2
# 8.197092545665603
# 387
# empty queue
# empty queue
# ue-number sched1: 2
# 12.658541742675864
# 389
# empty queue
# ue-number sched1: 2
# 7.793688660887951
# 389
# empty queue
# ue-number sched1: 0
# 5.975927487260697
# 389
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 8.013109215230859
# 393
# empty queue
# ue-number sched1: 0
# 6.100721459365088
# 393
# empty queue
# ue-number sched1: 0
# 12.326926017140629
# 393
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 1
# 4.453391214437554
# 395
# empty queue
# ue-number sched1: 0
# 12.173042314913571
# 395
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 14.001184043991064
# 397
# empty queue
# empty queue
# ue-number sched1: 0
# 7.152141742301839
# 397
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 11.885100188493016
# 399
# empty queue
# empty queue
# ue-number sched1: 0
# 13.513144788027343
# 401
# empty queue
# empty queue
# ue-number sched1: 1
# 10.49512655792349
# 401
# ue-number sched1: 0
# 23.520907003877987
# 401
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 7.00700243696056
# 403
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 10.303080783921745
# 405
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 2
# 8.386526951907458
# 407
# empty queue
# empty queue
# ue-number sched1: 2
# 12.736748906852872
# 409
# empty queue
# ue-number sched1: 2
# 7.803309001551338
# 409
# empty queue
# ue-number sched1: 0
# 6.2193667419820695
# 409
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 8.204329608824413
# 413
# empty queue
# ue-number sched1: 0
# 6.192336767744372
# 413
# empty queue
# ue-number sched1: 0
# 12.412529158944809
# 413
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 1
# 4.624052266224839
# 415
# empty queue
# ue-number sched1: 0
# 12.26199854414905
# 415
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 14.045404455137001
# 417
# empty queue
# empty queue
# ue-number sched1: 0
# 7.362423996938077
# 417
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 11.980186523778842
# 419
# empty queue
# empty queue
# ue-number sched1: 0
# 13.568700175147091
# 421
# empty queue
# empty queue
# ue-number sched1: 1
# 10.623153834117268
# 421
# ue-number sched1: 0
# 23.336145276292477
# 421
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 7.217797714243613
# 423
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 10.434496896588026
# 425
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 2
# 8.562708673353685
# 427
# empty queue
# empty queue
# ue-number sched1: 2
# 12.809626368110491
# 429
# empty queue
# ue-number sched1: 2
# 7.812052727794815
# 429
# empty queue
# ue-number sched1: 0
# 6.445796340525034
# 429
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 8.382352231340677
# 433
# empty queue
# ue-number sched1: 0
# 6.275499770149215
# 433
# empty queue
# ue-number sched1: 0
# 12.492330692865936
# 433
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 1
# 4.7790227388841835
# 435
# empty queue
# ue-number sched1: 0
# 12.344944583522915
# 435
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 14.086744459612515
# 437
# empty queue
# empty queue
# ue-number sched1: 0
# 7.558304470400933
# 437
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 12.068891128756807
# 439
# empty queue
# empty queue
# ue-number sched1: 0
# 13.620618870829606
# 441
# empty queue
# empty queue
# ue-number sched1: 1
# 10.742562415247317
# 441
# ue-number sched1: 0
# 23.164267204017523
# 441
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 7.414348091835159
# 443
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 10.557138412977997
# 445
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 2
# 10.467828828477455
# 447
# empty queue
# empty queue
# ue-number sched1: 2
# 12.877756717204205
# 449
# empty queue
# ue-number sched1: 2
# 7.820035282048457
# 449
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 8.548632367626837
# 453
# empty queue
# ue-number sched1: 0
# 6.351329458098457
# 453
# empty queue
# ue-number sched1: 0
# 12.566961108189192
# 453
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 1
# 4.9203722791123905
# 455
# empty queue
# ue-number sched1: 0
# 12.42253150717635
# 455
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 14.125506539678428
# 457
# empty queue
# empty queue
# ue-number sched1: 0
# 7.741359105770732
# 457
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 12.15190067042462
# 459
# empty queue
# empty queue
# ue-number sched1: 0
# 13.669283995496558
# 461
# empty queue
# empty queue
# ue-number sched1: 1
# 10.85428125600582
# 461
# ue-number sched1: 0
# 23.00384591854432
# 461
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 7.598192401681914
# 463
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 10.67194355771302
# 465
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 2
# 10.58408333405594
# 467
# empty queue
# empty queue
# ue-number sched1: 2
# 12.941636836171533
# 469
# empty queue
# ue-number sched1: 2
# 7.827352618939509
# 469
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 14.715850221475177
# 473
# empty queue
# ue-number sched1: 0
# 6.420755577646801
# 473
# empty queue
# ue-number sched1: 0
# 12.636958682473859
# 473
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 1
# 5.049821801445721
# 475
# empty queue
# ue-number sched1: 0
# 12.495315469531246
# 475
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 14.161950286198236
# 477
# empty queue
# empty queue
# ue-number sched1: 0
# 7.91293222590502
# 477
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 12.229802374052003
# 479
# empty queue
# empty queue
# ue-number sched1: 0
# 13.715024219941734
# 481
# empty queue
# empty queue
# ue-number sched1: 1
# 10.959104647557307
# 481
# ue-number sched1: 0
# 22.853666091393592
# 481
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 7.7706460920750775
# 483
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 10.779715598105255
# 485
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 2
# 10.693242618794475
# 487
# empty queue
# empty queue
# ue-number sched1: 2
# 13.001693489840855
# 489
# empty queue
# ue-number sched1: 2
# 7.834085159214631
# 489
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 14.73911660387087
# 493
# empty queue
# ue-number sched1: 0
# 6.484557021648147
# 493
# empty queue
# ue-number sched1: 0
# 12.702786158593167
# 493
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 1
# 5.168813978422181
# 495
# empty queue
# ue-number sched1: 0
# 12.56377481839115
# 495
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 14.196299937358816
# 497
# empty queue
# empty queue
# ue-number sched1: 0
# 8.074178574936456
# 497
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 12.303101834492582
# 499
# empty queue
# empty queue
# ue-number sched1: 0
# 13.758123352265047
# 501
# empty queue
# empty queue
# ue-number sched1: 1
# 11.057716350667267
# 501
# ue-number sched1: 0
# 22.712685285802078
# 501
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 7.932841294227356
# 503
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 10.881146849332032
# 505
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 2
# 10.796002552762344
# 507
# empty queue
# empty queue
# ue-number sched1: 2
# 13.058295580373393
# 509
# empty queue
# ue-number sched1: 2
# 7.840300817282572
# 509
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 14.761124616430207
# 513
# empty queue
# ue-number sched1: 0
# 6.543391238825403
# 513
# empty queue
# ue-number sched1: 0
# 12.764843872860792
# 513
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 1
# 5.278567295833979
# 515
# empty queue
# ue-number sched1: 0
# 12.62832357747928
# 515
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 14.228750355434387
# 517
# empty queue
# empty queue
# ue-number sched1: 0
# 8.226096388933378
# 517
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 12.372237072877859
# 519
# empty queue
# empty queue
# ue-number sched1: 0
# 13.798827935685754
# 521
# empty queue
# empty queue
# ue-number sched1: 1
# 11.15070864037725
# 521
# ue-number sched1: 0
# 22.580003596689476
# 521
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 8.085758436875695
# 523
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 10.976837654677558
# 525
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 2
# 10.892966891228204
# 527
# empty queue
# empty queue
# ue-number sched1: 2
# 13.111763878194486
# 529
# empty queue
# ue-number sched1: 2
# 7.846057346309534
# 529
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 14.781984980451107
# 533
# empty queue
# ue-number sched1: 0
# 6.597817020081186
# 533
# empty queue
# ue-number sched1: 0
# 12.823480194424672
# 533
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 1
# 5.380117976542055
# 535
# empty queue
# ue-number sched1: 0
# 12.689322175757136
# 535
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 14.259471810749911
# 537
# empty queue
# empty queue
# ue-number sched1: 0
# 8.369553674525628
# 537
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 12.437589740388296
# 539
# empty queue
# empty queue
# ue-number sched1: 0
# 13.83735332790292
# 541
# empty queue
# empty queue
# ue-number sched1: 1
# 11.23859748426782
# 541
# ue-number sched1: 0
# 22.45483955801674
# 541
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 8.230251439132237
# 543
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 11.067311539202747
# 545
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 2
# 10.984662399423444
# 547
# empty queue
# empty queue
# ue-number sched1: 2
# 13.162378821994547
# 549
# empty queue
# ue-number sched1: 2
# 7.85140417400454
# 549
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 14.801795165619053
# 553
# empty queue
# ue-number sched1: 0
# 6.648312339246214
# 553
# empty queue
# ue-number sched1: 0
# 12.878999904003015
# 553
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 1
# 5.4743528348729935
# 555
# empty queue
# ue-number sched1: 0
# 12.74708606481874
# 555
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 14.288613844747253
# 557
# empty queue
# empty queue
# ue-number sched1: 0
# 8.505309285475077
# 557
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 12.4994941296596
# 559
# empty queue
# empty queue
# ue-number sched1: 0
# 13.873888608547905
# 561
# empty queue
# empty queue
# ue-number sched1: 1
# 11.321834749593934
# 561
# ue-number sched1: 0
# 22.33651084445683
# 561
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 8.367067968957205
# 563
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 11.153027416943576
# 565
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 2
# 11.071551046308155
# 567
# empty queue
# empty queue
# ue-number sched1: 2
# 13.210386825337732
# 569
# empty queue
# ue-number sched1: 2
# 7.856383853754259
# 569
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 14.820641368483578
# 573
# empty queue
# ue-number sched1: 0
# 6.695288456953895
# 573
# empty queue
# ue-number sched1: 0
# 12.93167097649211
# 573
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 1
# 5.5620352710518866
# 575
# empty queue
# ue-number sched1: 0
# 12.801892699134996
# 575
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 14.316308414882037
# 577
# empty queue
# empty queue
# ue-number sched1: 0
# 8.63402997247613
# 577
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 12.558244483855622
# 579
# empty queue
# empty queue
# ue-number sched1: 0
# 13.908600573018813
# 581
# empty queue
# empty queue
# ue-number sched1: 1
# 11.400818103475666
# 581
# ue-number sched1: 0
# 22.224418679724852
# 581
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 8.496865870666223
# 583
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 11.234389506036512
# 585
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 2
# 11.154039916186791
# 587
# empty queue
# empty queue
# ue-number sched1: 2
# 13.25600541677829
# 589
# empty queue
# ue-number sched1: 2
# 7.861033222050526
# 589
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 14.838600140741926
# 593
# empty queue
# ue-number sched1: 0
# 6.739101170093646
# 593
# empty queue
# ue-number sched1: 0
# 12.981730115104867
# 593
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 1
# 5.643826020638585
# 595
# empty queue
# ue-number sched1: 0
# 12.853987234795989
# 595
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 14.342672474212966
# 597
# empty queue
# empty queue
# ue-number sched1: 0
# 8.756304285274663
# 597
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 12.614100971172395
# 599
# empty queue
# empty queue
# ue-number sched1: 0
# 13.941637007388952
# 601
# empty queue
# empty queue
# ue-number sched1: 1
# 11.475899104614243
# 601
# ue-number sched1: 0
# 22.118035138930527
# 601
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 8.620226589552274
# 603
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 11.311755443925268
# 605
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 2
# 11.232489326659634
# 607
# empty queue
# empty queue
# ue-number sched1: 2
# 13.29942746044035
# 609
# empty queue
# ue-number sched1: 2
# 7.865384329366403
# 609
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 14.855739738400956
# 613
# empty queue
# ue-number sched1: 0
# 6.780059858892367
# 613
# empty queue
# ue-number sched1: 0
# 13.029387300091134
# 613
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 1
# 5.720299853548198
# 615
# empty queue
# ue-number sched1: 0
# 12.903587216071879
# 615
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 14.367810102151209
# 617
# empty queue
# empty queue
# ue-number sched1: 0
# 8.872653991872044
# 617
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 12.667294603751252
# 619
# empty queue
# empty queue
# ue-number sched1: 0
# 13.973129392681159
# 621
# empty queue
# empty queue
# ue-number sched1: 1
# 11.547389864660111
# 621
# ue-number sched1: 0
# 22.016892731111717
# 621
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 8.737666221748457
# 623
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 11.385442976707354
# 625
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 2
# 11.30721952453763
# 627
# empty queue
# empty queue
# ue-number sched1: 2
# 13.340824645544878
# 629
# empty queue
# ue-number sched1: 2
# 7.869465194630876
# 629
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 14.872121246734286
# 633
# empty queue
# ue-number sched1: 0
# 6.818434818811546
# 633
# empty queue
# ue-number sched1: 0
# 13.07482955309971
# 633
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 1
# 5.791959116082097
# 635
# empty queue
# ue-number sched1: 0
# 12.950886455803216
# 635
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 14.391814275970155
# 637
# empty queue
# empty queue
# ue-number sched1: 0
# 8.983543522630148
# 637
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 12.718031314740996
# 639
# empty queue
# empty queue
# ue-number sched1: 0
# 14.00319515255648
# 641
# empty queue
# empty queue
# ue-number sched1: 1
# 11.615568568931103
# 641
# ue-number sched1: 0
# 21.920575793542348
# 641
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 8.849644670532172
# 643
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 11.455735509716888
# 645
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 2
# 11.378516245206335
# 647
# empty queue
# empty queue
# ue-number sched1: 2
# 13.38035039011602
# 649
# empty queue
# ue-number sched1: 2
# 7.87330042114504
# 649
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 14.887799523839181
# 653
# empty queue
# ue-number sched1: 0
# 6.854463245044946
# 653
# empty queue
# ue-number sched1: 0
# 13.118224072313241
# 653
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 1
# 5.859244791045733
# 655
# empty queue
# ue-number sched1: 0
# 12.996058268685884
# 655
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 14.414768352629485
# 657
# empty queue
# empty queue
# ue-number sched1: 0
# 9.089387830869375
# 657
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 12.766495358787695
# 659
# empty queue
# empty queue
# ue-number sched1: 0
# 14.03193953292366
# 661
# empty queue
# empty queue
# ue-number sched1: 1
# 11.680684080488817
# 661
# ue-number sched1: 0
# 21.828713336997254
# 661
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 8.956573281128192
# 663
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 11.522886741711366
# 665
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 2
# 11.44663535674278
# 667
# empty queue
# empty queue
# ue-number sched1: 2
# 13.418142271769181
# 669
# empty queue
# ue-number sched1: 2
# 7.876911702773912
# 669
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 14.902823996428092
# 673
# empty queue
# ue-number sched1: 0
# 6.888354149944194
# 673
# empty queue
# ue-number sched1: 0
# 13.159720859104503
# 673
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 1
# 5.92254559093607
# 675
# empty queue
# ue-number sched1: 0
# 13.039258181343776
# 675
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 14.436747315361222
# 677
# empty queue
# empty queue
# ue-number sched1: 0
# 9.190558974590084
# 677
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 12.81285216486298
# 679
# empty queue
# empty queue
# ue-number sched1: 0
# 14.059457182733837
# 681
# empty queue
# empty queue
# ue-number sched1: 1
# 11.742959802284142
# 681
# ue-number sched1: 0
# 21.740973061577208
# 681
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 9.058821244164836
# 683
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 11.587124556364676
# 685
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 2
# 11.511806761790979
# 687
# empty queue
# empty queue
# ue-number sched1: 2
# 13.454324074079842
# 689
# empty queue
# ue-number sched1: 2
# 7.880318242583561
# 689
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 14.917239334486194
# 693
# empty queue
# ue-number sched1: 0
# 6.920292428964657
# 693
# empty queue
# ue-number sched1: 0
# 13.199454930973666
# 693
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 1
# 5.9822054805712455
# 695
# empty queue
# ue-number sched1: 0
# 13.080626216477055
# 695
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 14.45781882797624
# 697
# empty queue
# empty queue
# ue-number sched1: 0
# 9.287391658249682
# 697
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 12.857250742789724
# 699
# empty queue
# empty queue
# ue-number sched1: 0
# 14.08583349059432
# 701
# empty queue
# empty queue
# ue-number sched1: 1
# 11.802596934735591
# 701
# ue-number sched1: 0
# 21.65705632339535
# 701
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 9.156720995890886
# 703
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 11.648654307836354
# 705
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 2
# 11.574237693516485
# 707
# empty queue
# empty queue
# ue-number sched1: 2
# 13.48900751844301
# 709
# empty queue
# ue-number sched1: 2
# 7.883537101113864
# 709
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 14.931086026031906
# 713
# empty queue
# ue-number sched1: 0
# 6.950442242335642
# 713
# empty queue
# ue-number sched1: 0
# 13.237548195703464
# 713
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 1
# 6.038529936798695
# 715
# empty queue
# ue-number sched1: 0
# 13.120288828066949
# 715
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 14.478044131035224
# 717
# empty queue
# empty queue
# ue-number sched1: 0
# 9.380187923442707
# 717
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 12.899825723764412
# 719
# empty queue
# empty queue
# ue-number sched1: 0
# 14.111145720613766
# 721
# empty queue
# empty queue
# ue-number sched1: 1
# 11.85977723755786
# 721
# ue-number sched1: 0
# 21.5766938786541
# 721
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 9.250572795838384
# 723
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 11.707661608912428
# 725
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 2
# 11.634115513852404
# 727
# empty queue
# empty queue
# ue-number sched1: 2
# 13.522293737051683
# 729
# empty queue
# ue-number sched1: 2
# 7.886583487722454
# 729
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 14.944400869029586
# 733
# empty queue
# ue-number sched1: 0
# 6.978949843155923
# 733
# empty queue
# ue-number sched1: 0
# 13.274111046421185
# 733
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 1
# 6.091791185922495
# 735
# empty queue
# ue-number sched1: 0
# 13.158360548987488
# 735
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 14.497478807210635
# 737
# empty queue
# empty queue
# ue-number sched1: 0
# 9.469221138824478
# 737
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 12.94069909894364
# 739
# empty queue
# empty queue
# ue-number sched1: 0
# 14.135463982214155
# 741
# empty queue
# empty queue
# ue-number sched1: 1
# 11.914665382656306
# 741
# ue-number sched1: 0
# 21.499642267149273
# 741
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 9.340648626069008
# 743
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 11.764314708387893
# 745
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 2
# 11.691610100536245
# 747
# empty queue
# empty queue
# ue-number sched1: 2
# 13.554274531561779
# 749
# empty queue
# ue-number sched1: 2
# 7.889471005579186
# 749
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 14.957217394228634
# 753
# empty queue
# ue-number sched1: 0
# 7.005945954840263
# 753
# empty queue
# ue-number sched1: 0
# 13.309243725434035
# 753
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 1
# 6.142232608474589
# 755
# empty queue
# ue-number sched1: 0
# 13.194945400248267
# 755
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 14.516173437852816
# 757
# empty queue
# empty queue
# ue-number sched1: 0
# 9.554739409777916
# 757
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 12.97998170755349
# 759
# empty queue
# empty queue
# ue-number sched1: 0
# 14.158852061884138
# 761
# empty queue
# empty queue
# ue-number sched1: 1
# 11.967410967812906
# 761
# ue-number sched1: 0
# 21.425680724729514
# 761
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 9.4271955277545
# 763
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 11.818766527383504
# 765
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 2
# 11.746875892534897
# 767
# empty queue
# empty queue
# ue-number sched1: 2
# 13.585033453380154
# 769
# empty queue
# ue-number sched1: 2
# 7.892211858700134
# 769
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 14.969566230123764
# 773
# empty queue
# ue-number sched1: 0
# 7.031547779536069
# 773
# empty queue
# ue-number sched1: 0
# 13.343037495468842
# 773
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 1
# 6.190072461791915
# 775
# empty queue
# ue-number sched1: 0
# 13.230138101613862
# 775
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 14.534174168602235
# 777
# empty queue
# empty queue
# ue-number sched1: 0
# 9.636968505023109
# 777
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 13.017774516113445
# 779
# empty queue
# empty queue
# ue-number sched1: 0
# 14.181368139542073
# 781
# empty queue
# empty queue
# ue-number sched1: 1
# 12.018150247515639
# 781
# ue-number sched1: 0
# 21.354608535684182
# 781
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 9.510438468630037
# 783
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 11.87115641098651
# 785
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 2
# 11.800053650202269
# 787
# empty queue
# empty queue
# ue-number sched1: 2
# 13.614646734728769
# 789
# empty queue
# ue-number sched1: 2
# 7.894817027717204
# 789
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 14.981475419186452
# 793
# empty queue
# ue-number sched1: 0
# 7.055860702659915
# 793
# empty queue
# ue-number sched1: 0
# 13.375575649681686
# 793
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 1
# 6.235507040569434
# 795
# empty queue
# ue-number sched1: 0
# 13.26402511588509
# 795
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 14.551523198593133
# 797
# empty queue
# empty queue
# ue-number sched1: 0
# 9.716114379048689
# 797
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 13.054169722591345
# 799
# empty queue
# empty queue
# ue-number sched1: 0
# 14.203065407984269
# 801
# empty queue
# empty queue
# ue-number sched1: 1
# 12.067007626745577
# 801
# ue-number sched1: 0
# 21.286242752880174
# 801
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 9.590582817359067
# 803
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 11.921611641109546
# 805
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 2
# 11.851271976051683
# 807
# empty queue
# empty queue
# ue-number sched1: 2
# 13.643184094271406
# 809
# empty queue
# ue-number sched1: 2
# 7.897296419761873
# 809
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 14.99297069288625
# 813
# empty queue
# ue-number sched1: 0
# 7.078979745881262
# 813
# empty queue
# ue-number sched1: 0
# 13.406934386049176
# 813
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 1
# 6.278713371959662
# 815
# empty queue
# ue-number sched1: 0
# 13.296685553215982
# 815
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 14.568259205171696
# 817
# empty queue
# empty queue
# ue-number sched1: 0
# 9.792365354741845
# 817
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# 13.089251713138843
# 819
# empty queue
# empty queue
# ue-number sched1: 0
# 14.223992610559806
# 821
# empty queue
# empty queue
# ue-number sched1: 1
# 12.114096955177976
# 821
# ue-number sched1: 0
# 21.220416226791976
# 821
# empty queue
# empty queue
# empty queue
# ue-number sched1: 0
# ...
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue
# empty queue

# %%
for i in np.arange(len(ue_comp)):
    if(ue_comp[i].qos==2):
        stream=i
    if(ue_comp[i].qos==1):    
        rt=i
    if(ue_comp[i].qos==0):
        nrt=i

plt.figure(figsize=(12,6))
#plt.plot(list(ue_comp[stream].mon.keys())[1000:3000],list(ue_comp[stream].mon.values())[1000:3000],label='UE1 - streamer')
plt.plot(list(ue_comp[rt].mon.keys())[1000:3000],list(ue_comp[rt].mon.values())[1000:3000],label='UE2 - RT')
#plt.plot(list(ue_comp[nrt].mon.keys())[1000:3000],list(ue_comp[nrt].mon.values())[1000:3000],label='UE3 - NRT')
#plt.plot(list(ue_list[120].mon.keys())[1000:3000],list(ue_list[120].mon.values())[1000:3000],label='UE4')
plt.xlabel('Time-Slots in [1 ms]')
plt.ylabel('Bits in buffer')
plt.legend(loc="upper left")
plt.grid()
#plt.axvline(x = 13, color = 'b', label = 'axvline - full height')
#plt.axvline(x = 27, color = 'b', label = 'axvline - full height')

# %%
for i in np.arange(len(ue_list)):
    if(ue_list[i].qos==2):
        stream=i
    if(ue_list[i].qos==1):    
        rt=i
    if(ue_list[i].qos==0):
        nrt=i

plt.figure(figsize=(12,6))
#plt.plot(list(ue_list[stream].mon.keys())[1000:3000],list(ue_list[stream].mon.values())[1000:3000],label='UE1 - streamer')
plt.plot(list(ue_list[rt].mon.keys())[1000:3000],list(ue_list[rt].mon.values())[1000:3000],label='UE2 - RT')
#plt.plot(list(ue_list[nrt].mon.keys())[1000:3000],list(ue_list[nrt].mon.values())[1000:3000],label='UE3 - NRT')
#plt.plot(list(ue_list[120].mon.keys())[1000:3000],list(ue_list[120].mon.values())[1000:3000],label='UE4')
plt.xlabel('Time-Slots in [1 ms]')
plt.ylabel('Bits in buffer')
plt.legend(loc="upper left")
plt.grid()
#plt.axvline(x = 13, color = 'b', label = 'axvline - full height')
#plt.axvline(x = 27, color = 'b', label = 'axvline - full height')

# %%
ue_list=ue_dict[19]
for i in ue_list:
    print('User')
    print(i.bits)
    print(i.mR)
    print(i.bits2)
    print(i.mR2)
    print(i.comp)
# Out:
# User
# 24000
# 10.314315250305196
# 24000
# 4.7996711144864985
# 0
# User
# 24000
# 9.69751506060959
# 24000
# 4.800120686340527
# 0
# User
# 24000
# 11.450533659224037
# 24000
# 4.798347054917154
# 0
# User
# 24000
# 10.046038796724648
# 24000
# 4.799880302705694
# 0
# User
# 24000
# 10.125198101579565
# 24000
# 4.799821026669424
# 0
# User
# 24000
# 10.63950925853783
# 24000
# 4.79938038147131
# 0
# User
# 24000
# 9.69751506060959
# 24000
# 4.800120686340527
# 0
# User
# 24000
# 10.946054051824346
# 24000
# 4.799055498157317
# 0
# User
# 24000
# 9.82867924304049
# 24000
# 4.800033861962557
# 0
# User
# 24000
# 11.361199291734433
# 24000
# 4.798494310696682
# 0
# User
# 24000
# 10.862275911255505
# 24000
# 4.799150267890434
# 0
# User
# 24000
# 10.63950925853783
# 24000
# 4.79938038147131
# 0
# User
# 24000
# 10.332689572506773
# 24000
# 4.799655870796071
# 0
# User
# 24000
# 11.604327152882181
# 24000
# 4.798062792945333
# 0
# User
# 24000
# 12.34393852741856
# 24000
# 4.795718893732559
# 0
# User
# 24000
# 10.000290940172091
# 24000
# 4.799913705822508
# 0
# User
# 24000
# 10.109059080364956
# 24000
# 4.799833268495085
# 0
# User
# 24000
# 11.450533659224037
# 24000
# 4.798347054917154
# 0
# User
# 24000
# 10.225557852262536
# 24000
# 4.7997430062829896
# 0
# User
# 24000
# 9.856123480311858
# 24000
# 4.800015165888953
# 0
# User
# 24000
# 10.191404597685452
# 24000
# 4.79976993261281
# 0
# User
# 24000
# 10.061570555739449
# 24000
# 4.799868822381306
# 0
# User
# 24000
# 9.69751506060959
# 24000
# 4.800120686340527
# 0
# User
# 24000
# 10.75859634541917
# 24000
# 4.799261031703393
# 0
# User
# 24000
# 12.184912413735674
# 24000
# 4.796417432264813
# 0
# User
# 24000
# 11.498767425081471
# 24000
# 4.798262412106392
# 0
# User
# 24000
# 10.783745892345827
# 24000
# 4.79923478328784
# 0
# User
# 24000
# 10.314315250305196
# 24000
# 4.7996711144864985
# 0
# User
# 24000
# 9.80165810561555
# 24000
# 4.800052086233566
# 0
# User
# 24000
# 11.03610138571277
# 24000
# 4.7989477363197475
# 0
# User
# 24000
# 9.97046841373061
# 24000
# 4.799935158236228
# 0
# User
# 24000
# 9.856123480311858
# 24000
# 4.800015165888953
# 0
# User
# 24000
# 10.332689572506773
# 24000
# 4.799655870796071
# 0
# User
# 24000
# 10.975313641580364
# 24000
# 4.799021186133024
# 0
# User
# 24000
# 11.450533659224037
# 24000
# 4.798347054917154
# 0
# User
# 24000
# 10.862275911255505
# 24000.0
# 4.799568078721401
# 0
# User
# 24000
# 12.34393852741856
# 24000
# 4.795718893732559
# 0
# User
# 24000
# 10.046038796724648
# 24000
# 4.799880302705694
# 0
# User
# 24000
# 10.467930990932269
# 24000
# 4.799539560671649
# 0
# User
# 24000
# 9.722986508658453
# 24000
# 4.800104142289381
# 0
# User
# 24000
# 9.80165810561555
# 24000
# 4.800052086233566
# 0
# User
# 24000
# 11.795439996517501
# 24000
# 4.79764014039234
# 0
# User
# 24000
# 9.985313993265242
# 24000
# 4.799924510596432
# 0
# User
# 24000
# 10.835558506980611
# 24000
# 4.799179469431454
# 0
# User
# 24000
# 9.735859312880113
# 24000
# 4.800095724441369
# 0
# User
# 24000
# 10.046038796724648
# 24000
# 4.799880302705694
# 0
# User
# 24000
# 11.959868014135772
# 24000
# 4.797194503251885
# 0
# User
# 24000
# 11.662784463851361
# 24000
# 4.797942676916293
# 0
# User
# 24000
# 10.408476289141023
# 24000.0
# 4.803296231266505
# 0
# User
# 24000
# 9.722986508658453
# 24000
# 4.800104142289381
# 0
# User
# 24000
# 10.015402084106272
# 24000
# 4.799902739414233
# 0
# User
# 24000
# 10.061570555739449
# 24000
# 4.799868822381306
# 0
# User
# 24000
# 9.912346479506974
# 24000
# 4.800909810549574
# 0
# User
# 24000
# 12.061608879876555
# 24000
# 4.79687032515183
# 0
# User
# 24000
# 10.594632965865843
# 24000
# 4.799423385767714
# 0
# User
# 24000
# 10.296156462934443
# 24000
# 4.799686055110041
# 0
# User
# 24000
# 11.279588775592357
# 24000
# 4.798619233736843
# 0
# User
# 24000
# 11.450533659224037
# 24000
# 4.798347054917154
# 0
# User
# 24000
# 10.616890535321057
# 24000
# 4.799402184560593
# 0

# %%
C=0
nC=0
for i in ue_all:
    print('C:', i.mR)
    print('nC:',i.mR2)
    print('C-queue:', i.queue.level)
    print('nC-queue:',i.queue2.level)
    print('nC-queue:',i.qos)
    nC=nC+i.mR2
    C=C+i.mR
# Out:
# C: 29.04834825256819
# nC: 40.24650948133838
# C-queue: 145063.75
# nC-queue: 0.0
# nC-queue: 0.0
# C: 18.997834588295053
# nC: 39.62473559849142
# C-queue: 147800.0
# nC-queue: 0.0
# nC-queue: 0.0
# C: 16.689717104584005
# nC: 39.010115737289674
# C-queue: 155984.0
# nC-queue: 5126.0
# nC-queue: 0.0
# C: 21.425058106495676
# nC: 38.415939622502435
# C-queue: 137240.0
# nC-queue: 2000.0
# nC-queue: 0.0
# C: 26.509244815431224
# nC: 38.4227224082082
# C-queue: 121862.5
# nC-queue: 0.0
# nC-queue: 0.0
# C: 16.749988814332006
# nC: 38.935060242591135
# C-queue: 153522.0
# nC-queue: 3516.0
# nC-queue: 0.0
# C: 666.7666666666667
# nC: 25.17079642031401
# C-queue: 196000
# nC-queue: 13910.0
# nC-queue: 0.0
# C: 23.896751377754352
# nC: 39.62908073764961
# C-queue: 134731.25
# nC-queue: 0.0
# nC-queue: 0.0
# C: 29.032856011344425
# nC: 38.80409427774533
# C-queue: 117675.0
# nC-queue: 0.0
# nC-queue: 0.0
# C: 34.81721671921156
# nC: 39.59131294335578
# C-queue: 105810.0
# nC-queue: 0.0
# nC-queue: 0.0
# C: 21.338052060414203
# nC: 40.03332970850886
# C-queue: 143845.0
# nC-queue: 0.0
# nC-queue: 0.0
# C: 2000.1
# nC: 26.811307798688066
# C-queue: 198000
# nC-queue: 0.0
# nC-queue: 0.0
# C: 10.847422841630939
# nC: 25.304976062205395
# C-queue: 171164.0
# nC-queue: 73550.0
# nC-queue: 0.0
# C: 0.1
# nC: 25.474058364860234
# C-queue: 192000
# nC-queue: 0.0
# nC-queue: 0.0
# C: 0.1
# nC: 25.248659002118636
# C-queue: 198000
# nC-queue: 13456.0
# nC-queue: 0.0
# C: 26.33909966109124
# nC: 39.202157255134935
# C-queue: 127025.0
# nC-queue: 0.0
# nC-queue: 0.0
# C: 29.176088604626674
# nC: 39.621090407446786
# C-queue: 121408.75
# nC-queue: 0.0
# nC-queue: 0.0
# C: 0.1
# nC: 25.185006950682766
# C-queue: 200000
# nC-queue: 15716.0
# nC-queue: 0.0
# C: 0.1
# nC: 26.069284939285335
# C-queue: 196000
# nC-queue: 0.0
# nC-queue: 0.0
# C: 31.847118944013637
# nC: 39.231009956653644
# C-queue: 112900.0
# nC-queue: 0.0
# nC-queue: 0.0
# C: 14.621282852553671
# nC: 33.93128809323981
# C-queue: 155614.0
# nC-queue: 24420.0
# nC-queue: 0.0
# C: 23.837213962366718
# nC: 38.838480527960364
# C-queue: 132255.0
# nC-queue: 0.0
# nC-queue: 0.0
# C: 12.65327502629417
# nC: 29.521698946965568
# C-queue: 166876.0
# nC-queue: 52606.0
# nC-queue: 0.0
# C: 26.48644509203334
# nC: 39.5860148514274
# C-queue: 131350.0
# nC-queue: 0.0
# nC-queue: 0.0
# C: 0.1
# nC: 25.551551956964985
# C-queue: 192000
# nC-queue: 0.0
# nC-queue: 0.0
# C: 18.936748958988673
# nC: 39.54064409058675
# C-queue: 151000.0
# nC-queue: 0.0
# nC-queue: 0.0
# C: 0.1
# nC: 25.19515586914362
# C-queue: 196000
# nC-queue: 11248.0
# nC-queue: 0.0
# C: 14.654075461530118
# nC: 34.07807912058217
# C-queue: 162640.0
# nC-queue: 27610.0
# nC-queue: 0.0
# C: 12.583900602706814
# nC: 29.484986144946216
# C-queue: 171006.0
# nC-queue: 57074.0
# nC-queue: 0.0
# C: 26.548732891878476
# nC: 40.82879298260504
# C-queue: 133940.0
# nC-queue: 0.0
# nC-queue: 0.0
# C: 34.843928812677056
# nC: 39.61619724357283
# C-queue: 105695.0
# nC-queue: 0.0
# nC-queue: 0.0
# C: 23.958872481624354
# nC: 40.03440738275163
# C-queue: 136797.5
# nC-queue: 0.0
# nC-queue: 0.0
# C: 16.729327427478452
# nC: 39.00037699425828
# C-queue: 153732.0
# nC-queue: 3194.0
# nC-queue: 0.0
# C: 34.8092139098816
# nC: 39.19358822096697
# C-queue: 104020.0
# nC-queue: 0.0
# nC-queue: 0.0
# C: 0.1
# nC: 26.06868726701506
# C-queue: 196000
# nC-queue: 0.0
# nC-queue: 0.0
# C: 34.56012967178335
# nC: 38.809480554179814
# C-queue: 161975.0
# nC-queue: 0.0
# nC-queue: 0.0
# C: 18.886860013104993
# nC: 39.616635891778785
# C-queue: 148350.0
# nC-queue: 0.0
# nC-queue: 0.0
# C: 34.65310452416455
# nC: 39.602473618241504
# C-queue: 107590.0
# nC-queue: 0.0
# nC-queue: 0.0
# C: 29.204357803300073
# nC: 39.22436034849562
# C-queue: 118965.0
# nC-queue: 0.0
# nC-queue: 0.0
# C: 26.47238501146269
# nC: 39.19422461755253
# C-queue: 126172.5
# nC-queue: 0.0
# nC-queue: 0.0
# C: 0.1
# nC: 21.425814762739392
# C-queue: 194000
# nC-queue: 37450.0
# nC-queue: 0.0
# C: 29.224129888089095
# nC: 39.196880053728066
# C-queue: 120207.5
# nC-queue: 0.0
# nC-queue: 0.0
# C: 10.803257353933692
# nC: 25.322129779543566
# C-queue: 169452.0
# nC-queue: 71514.0
# nC-queue: 0.0
# C: 21.44171544056994
# nC: 38.410732873121454
# C-queue: 136120.0
# nC-queue: 0.0
# nC-queue: 0.0
# C: 23.950698761810216
# nC: 39.18937615300609
# C-queue: 133195.0
# nC-queue: 0.0
# nC-queue: 0.0
# C: 31.874656638585847
# nC: 39.98126433757293
# C-queue: 119800.0
# nC-queue: 0.0
# nC-queue: 0.0
# C: 31.917711233568948
# nC: 39.18377909001452
# C-queue: 114500.0
# nC-queue: 0.0
# nC-queue: 0.0
# C: 14.525811303751702
# nC: 34.22039656724572
# C-queue: 161178.0
# nC-queue: 27014.0
# nC-queue: 0.0
# C: 34.848932743281566
# nC: 39.16996021959263
# C-queue: 106745.0
# nC-queue: 0
# nC-queue: 0.0
# C: 23.871970927950116
# nC: 39.98055360902002
# C-queue: 142428.75
# nC-queue: 0.0
# nC-queue: 0.0
# C: 300.1
# nC: 50.01073247117132
# C-queue: 374700
# nC-queue: 0.0
# nC-queue: 2.0
# C: 145.18684868614193
# nC: 74.99374885603092
# C-queue: 0.0
# nC-queue: 0
# nC-queue: 2.0
# C: 9.870009237664279
# nC: 4.800005633551151
# C-queue: 0
# nC-queue: 0
# nC-queue: 1.0
# C: 10.208389939333795
# nC: 4.799756591010651
# C-queue: 0
# nC-queue: 0
# nC-queue: 1.0
# C: 9.912346479506974
# nC: 4.7999762611951375
# C-queue: 0
# nC-queue: 0
# nC-queue: 1.0
# C: 9.955751468993439
# nC: 4.799945653057272
# C-queue: 0
# nC-queue: 0
# nC-queue: 1.0
# C: 10.278207061878705
# nC: 4.799700704094659
# C-queue: 0
# nC-queue: 0
# nC-queue: 1.0
# C: 0.1
# nC: 2.623695651545464
# C-queue: 24000
# nC-queue: 0
# nC-queue: 1.0
# C: 0.1
# nC: 2.542417016298616
# C-queue: 24000
# nC-queue: 0
# nC-queue: 1.0
# C: 0.1
# nC: 2.574397330485495
# C-queue: 24000
# nC-queue: 0
# nC-queue: 1.0
# C: 11.288052900518895
# nC: 4.798423938041876
# C-queue: 0
# nC-queue: 0
# nC-queue: 1.0
# C: 10.296156462934443
# nC: 4.799686055110041
# C-queue: 0
# nC-queue: 0
# nC-queue: 1.0
# C: 11.298855853541168
# nC: 4.799470348505661
# C-queue: 0
# nC-queue: 0
# nC-queue: 1.0
# C: 14.030825525074599
# nC: 4.803821274101875
# C-queue: 0
# nC-queue: 0
# nC-queue: 1.0
# C: 11.311678304582172
# nC: 4.798262412106392
# C-queue: 0.0
# nC-queue: 0
# nC-queue: 1.0
# C: 0.1
# nC: 2.4796061941377654
# C-queue: 24000
# nC-queue: 0.0
# nC-queue: 1.0
# C: 9.912346479506974
# nC: 4.7999762611951375
# C-queue: 0
# nC-queue: 0
# nC-queue: 1.0
# C: 9.775044962515102
# nC: 4.800069860853819
# C-queue: 0
# nC-queue: 0
# nC-queue: 1.0
# C: 9.92669301173932
# nC: 4.799966200639988
# C-queue: 0
# nC-queue: 0
# nC-queue: 1.0
# C: 25.141266098712173
# nC: 0.0
# C-queue: 0
# nC-queue: 24000
# nC-queue: 1.0
# C: 6.027850228972467
# nC: 0.1
# C-queue: 199320.0
# nC-queue: 200000
# nC-queue: 0.0
# C: 4.276650867021368
# nC: 0.1
# C-queue: 193600.0
# nC-queue: 202000
# nC-queue: 0.0
# C: 2.6998053494937
# nC: 0.1
# C-queue: 186700.0
# nC-queue: 192000
# nC-queue: 0.0
# C: 1.5173242762335957
# nC: 0.1
# C-queue: 191398.0
# nC-queue: 196000
# nC-queue: 0.0
# C: 4.131404634567919
# nC: 0.1
# C-queue: 189600.0
# nC-queue: 198000
# nC-queue: 0.0
# C: 1.658387880241574
# nC: 0.1
# C-queue: 195342.0
# nC-queue: 200000
# nC-queue: 0.0
# C: 3.009580013712642
# nC: 0.1
# C-queue: 191800.0
# nC-queue: 198000
# nC-queue: 0.0
# C: 2.8997975768705126
# nC: 0.1
# C-queue: 186248.75
# nC-queue: 194000
# nC-queue: 0.0
# C: 1.2269231105625662
# nC: 0.1
# C-queue: 194436.0
# nC-queue: 198000
# nC-queue: 0.0
# C: 2.159266719593547
# nC: 0.1
# C-queue: 194000.0
# nC-queue: 198000
# nC-queue: 0.0
# C: 2.892383601186671
# nC: 0.1
# C-queue: 192700.0
# nC-queue: 198000
# nC-queue: 0.0
# C: 438.6123585123585
# nC: 0.0
# C-queue: 192000.0
# nC-queue: 198000
# nC-queue: 0.0
# C: 4.215635523520578
# nC: 0.1
# C-queue: 191700.0
# nC-queue: 198000
# nC-queue: 0.0
# C: 3.633203095507581
# nC: 0.1
# C-queue: 186675.0
# nC-queue: 192000
# nC-queue: 0.0
# C: 28.9659793814433
# nC: 0.0
# C-queue: 191200.0
# nC-queue: 194000
# nC-queue: 0.0
# C: 1.9444279028639597
# nC: 0.1
# C-queue: 188640.0
# nC-queue: 192000
# nC-queue: 0.0
# C: 2049.786259444231
# nC: 0.0
# C-queue: 190000
# nC-queue: 196000
# nC-queue: 0.0
# C: 1.7507357768894718
# nC: 0.1
# C-queue: 190600.0
# nC-queue: 194000
# nC-queue: 0.0
# C: 1.256698860841318
# nC: 0.1
# C-queue: 194760.0
# nC-queue: 198000
# nC-queue: 0.0
# C: 104.24270915615519
# nC: 0.0
# C-queue: 194000.0
# nC-queue: 200000
# nC-queue: 0.0
# C: 65.94477727451715
# nC: 0.0
# C-queue: 189600.0
# nC-queue: 192000
# nC-queue: 0.0
# C: 380.7451612903226
# nC: 0.0
# C-queue: 198000.0
# nC-queue: 200000
# nC-queue: 0.0
# C: 3.3045177380747477
# nC: 0.1
# C-queue: 186675.0
# nC-queue: 192000
# nC-queue: 0.0
# C: 68.35361512791991
# nC: 0.0
# C-queue: 192000.0
# nC-queue: 194000
# nC-queue: 0.0
# C: 4.002247346467819
# nC: 0.1
# C-queue: 191700.0
# nC-queue: 198000
# nC-queue: 0.0
# C: 1.666027647937456
# nC: 0.1
# C-queue: 189280.0
# nC-queue: 192000
# nC-queue: 0.0
# C: 29.562552228094507
# nC: 0.1
# C-queue: 190000
# nC-queue: 192000
# nC-queue: 0.0
# C: 7.604662423359251
# nC: 0.1
# C-queue: 192440.0
# nC-queue: 196000
# nC-queue: 0.0
# C: 3.8344198974630688
# nC: 0.1
# C-queue: 192000.0
# nC-queue: 198000
# nC-queue: 0.0
# C: 3.946719998779426
# nC: 0.1
# C-queue: 183295.0
# nC-queue: 196000
# nC-queue: 0.0
# C: 1.453084105723059
# nC: 0.1
# C-queue: 192932.0
# nC-queue: 196000
# nC-queue: 0.0
# C: 2.236983728297871
# nC: 0.1
# C-queue: 195100.0
# nC-queue: 200000
# nC-queue: 0.0
# C: 1.6651278756603787
# nC: 0.1
# C-queue: 190056.0
# nC-queue: 194000
# nC-queue: 0.0
# C: 1.690805022275208
# nC: 0.1
# C-queue: 191960.0
# nC-queue: 194000
# nC-queue: 0.0
# C: 4.520887671729335
# nC: 0.1
# C-queue: 191320.0
# nC-queue: 192000
# nC-queue: 0.0
# C: 0.1
# nC: 0.0
# C-queue: 198000
# nC-queue: 198000
# nC-queue: 0.0
# C: 1.6481300599850057
# nC: 0.1
# C-queue: 190866.0
# nC-queue: 196000
# nC-queue: 0.0
# C: 1.6526678533002308
# nC: 0.1
# C-queue: 193920.0
# nC-queue: 198000
# nC-queue: 0.0
# C: 0.1
# nC: 0.0
# C-queue: 200000
# nC-queue: 200000
# nC-queue: 0.0
# C: 3.6357774517047488
# nC: 0.1
# C-queue: 188900.0
# nC-queue: 196000
# nC-queue: 0.0
# C: 4.175862815375235
# nC: 0.1
# C-queue: 187600.0
# nC-queue: 196000
# nC-queue: 0.0
# C: 3.7746330586743335
# nC: 0.1
# C-queue: 194000.0
# nC-queue: 200000
# nC-queue: 0.0
# C: 2.799123052990265
# nC: 0.1
# C-queue: 194965.0
# nC-queue: 200000
# nC-queue: 0.0
# C: 3.110090288450985
# nC: 0.1
# C-queue: 187800.0
# nC-queue: 194000
# nC-queue: 0.0
# C: 23.87510452559547
# nC: 0.0
# C-queue: 171393.75
# nC-queue: 198000
# nC-queue: 0.0
# C: 3.647407957725712
# nC: 0.1
# C-queue: 196000.0
# nC-queue: 200000
# nC-queue: 0.0
# C: 140.95912335527075
# nC: 0.0
# C-queue: 80000.0
# nC-queue: 200000
# nC-queue: 0.0
# C: 3.9237852569480873
# nC: 0.1
# C-queue: 193800.0
# nC-queue: 198000
# nC-queue: 0.0
# C: 1.2653407124979512
# nC: 0.1
# C-queue: 194760.0
# nC-queue: 198000
# nC-queue: 0.0
# C: 4.276966485885343
# nC: 0.1
# C-queue: 190125.0
# nC-queue: 198000
# nC-queue: 0.0
# C: 129.0267786543859
# nC: 0.1
# C-queue: 6120.0
# nC-queue: 375000
# nC-queue: 2.0
# C: 658.3077454475184
# nC: 0.0
# C-queue: 149250.0
# nC-queue: 375000
# nC-queue: 2.0
# C: 9.63480916310227
# nC: 0.1
# C-queue: 0
# nC-queue: 24000
# nC-queue: 1.0
# C: 10.35632201416224
# nC: 0.1
# C-queue: 0.0
# nC-queue: 24000
# nC-queue: 1.0
# C: 31.359847690594314
# nC: 0.0
# C-queue: 0
# nC-queue: 24000
# nC-queue: 1.0
# C: 10.905474789905465
# nC: 0.1
# C-queue: 0
# nC-queue: 24000
# nC-queue: 1.0
# C: 8.887865568503294
# nC: 0.0
# C-queue: 23200
# nC-queue: 24000
# nC-queue: 1.0
# C: 10.775562549883372
# nC: 0.1
# C-queue: 0.0
# nC-queue: 24000
# nC-queue: 1.0
# C: 9.877534680134362
# nC: 0.1
# C-queue: 0
# nC-queue: 24000
# nC-queue: 1.0
# C: 10.470953402360612
# nC: 0.1
# C-queue: 0
# nC-queue: 24000
# nC-queue: 1.0
# C: 10.429438954376682
# nC: 0.1
# C-queue: 0.0
# nC-queue: 24000
# nC-queue: 1.0
# C: 9.146013483911872
# nC: 0.1
# C-queue: 320.0
# nC-queue: 24000
# nC-queue: 1.0
# C: 11.020576465909173
# nC: 0.1
# C-queue: 0.0
# nC-queue: 24000
# nC-queue: 1.0
# C: 9.643276914277239
# nC: 0.1
# C-queue: 0.0
# nC-queue: 24000
# nC-queue: 1.0
# C: 9.518946645791504
# nC: 0.1
# C-queue: 310.0
# nC-queue: 24000
# nC-queue: 1.0
# C: 10.155863627069786
# nC: 0.1
# C-queue: 0
# nC-queue: 24000
# nC-queue: 1.0
# C: 10.13801129355227
# nC: 0.1
# C-queue: 0.0
# nC-queue: 24000
# nC-queue: 1.0
# C: 11.144178240212701
# nC: 0.1
# C-queue: 0
# nC-queue: 24000
# nC-queue: 1.0
# C: 10.487577263447994
# nC: 0.1
# C-queue: 0
# nC-queue: 24000
# nC-queue: 1.0
# C: 13.494153061388726
# nC: 0.0
# C-queue: 23040
# nC-queue: 24000
# nC-queue: 1.0

# %%
mean_tbs=0
for i in ue_all:
    mean_tbs+=i.tbs
    
mean_tbs=mean_tbs/len(ue_all)

mean_tbs2=0
ue_list=ue_dict[19]
for i in ue_list:
    mean_tbs2+=i.tbs
ue_list=ue_dict[20]
for i in ue_list:
    mean_tbs2+=i.tbs
    
mean_tbs2=mean_tbs2/(len(ue_dict[19])+len(ue_dict[20]))

# %%
print('all:',mean_tbs)
print('no comp:',mean_tbs2)
# Out:
# all: 58.31964285714286
# no comp: 66.11238532110092

# %%
ue_all_19=ue_all[0:69]
av=0
for i in ue_all_19:
    av+=i.mR2/i.mR
    print(i.mR2)
    print(i.mR)
av=av/70
# Out:
# 4.7996711144864985
# 10.314315250305196
# 4.800120686340527
# 9.69751506060959
# 4.798347054917154
# 11.450533659224037
# 4.799880302705694
# 10.046038796724648
# 4.799821026669424
# 10.125198101579565
# 4.79938038147131
# 10.63950925853783
# 2.653559591210679
# 1.0248554913294798
# 4.800120686340527
# 9.69751506060959
# 4.799055498157317
# 10.946054051824346
# 4.800033861962557
# 9.82867924304049
# 2.677001341260839
# 0.1
# 4.798494310696682
# 11.361199291734433
# 4.799150267890434
# 10.862275911255505
# 4.79938038147131
# 10.63950925853783
# 2.490796249677299
# 14.31336765222042
# 4.799655870796071
# 10.332689572506773
# 4.798062792945333
# 11.604327152882181
# 4.795718893732559
# 12.34393852741856
# 4.799913705822508
# 10.000290940172091
# 4.799833268495085
# 10.109059080364956
# 2.5193768326382333
# 6.208989934050677
# 4.798347054917154
# 11.450533659224037
# 4.7997430062829896
# 10.225557852262536
# 4.800015165888953
# 9.856123480311858
# 4.79976993261281
# 10.191404597685452
# 2.58691783983736
# 0.1
# 4.799868822381306
# 10.061570555739449
# 4.800120686340527
# 9.69751506060959
# 4.799261031703393
# 10.75859634541917
# 4.796417432264813
# 12.184912413735674
# 4.798262412106392
# 11.498767425081471
# 4.79923478328784
# 10.783745892345827
# 4.7996711144864985
# 10.314315250305196
# 4.800052086233566
# 9.80165810561555
# 4.7989477363197475
# 11.03610138571277
# 4.799935158236228
# 9.97046841373061
# 4.800015165888953
# 9.856123480311858
# 4.799655870796071
# 10.332689572506773
# 4.799021186133024
# 10.975313641580364
# 4.798347054917154
# 11.450533659224037
# 2.673120372548459
# 0.1
# 4.799568078721401
# 10.862275911255505
# 4.795718893732559
# 12.34393852741856
# 4.799880302705694
# 10.046038796724648
# 2.538069787022628
# 2.7229508196721315
# 4.799539560671649
# 10.467930990932269
# 4.800104142289381
# 9.722986508658453
# 2.6436774868070803
# 0.1
# 4.800052086233566
# 9.80165810561555
# 4.79764014039234
# 11.795439996517501
# 4.799924510596432
# 9.985313993265242
# 4.799179469431454
# 10.835558506980611
# 4.800095724441369
# 9.735859312880113
# 2.4836884412223275
# 12.407692307692308
# 4.799880302705694
# 10.046038796724648
# 4.797194503251885
# 11.959868014135772
# 4.797942676916293
# 11.662784463851361
# 4.803296231266505
# 10.408476289141023
# 4.800104142289381
# 9.722986508658453
# 4.799902739414233
# 10.015402084106272
# 4.799868822381306
# 10.061570555739449
# 4.800909810549574
# 9.912346479506974
# 4.79687032515183
# 12.061608879876555
# 4.799423385767714
# 10.594632965865843
# 2.5993017169583643
# 0.1
# 4.799686055110041
# 10.296156462934443
# 4.798619233736843
# 11.279588775592357
# 4.798347054917154
# 11.450533659224037
# 4.799402184560593
# 10.616890535321057

# %%
av
# Out:
# 2.327351787332842

# %%
print('comp prb perc',prb_number_comp/(prb_number_normal+prb_number_comp))
print('comp user perc',len(ue_comp)/len(ue_all))
# Out:
# comp prb perc 0.24
# comp user perc 0.2
