# %%
clear all

# %%
import pandas as pd
import numpy as np
import bibliothek as bib

# %%
df_ue = pd.read_json('Prepro/ue_data_051222.json')

# %%
df2 = pd.read_json("Prepro/cell_data.txt")

# %%
cells=df2['cell']
cell_list=np.array([])
for i in cells:
    cell_list=np.append(cell_list,i['pci'])
cell_list=cell_list.astype(int)

# %%
d={}
for i in df2.index:
    c=df2.loc[i]['cell']
    d.update({c['pci']:df2.loc[i]['pos']})

# %%
d
# Out:
# {168: [12.367383333333331, 51.339830555555565],
#  169: [12.367383333333331, 51.339830555555565],
#  170: [12.367383333333331, 51.339830555555565],
#  901: [12.377183333333335, 51.347266666666656],
#  902: [12.377183333333335, 51.347266666666656],
#  900: [12.377183333333335, 51.347266666666656],
#  377: [12.371591666666669, 51.34234166666668],
#  376: [12.371591666666669, 51.34234166666668],
#  375: [12.371591666666669, 51.34234166666668],
#  132: [12.379552777777777, 51.34256111111111],
#  134: [12.379552777777777, 51.34256111111111],
#  133: [12.379552777777777, 51.34256111111111],
#  320: [12.377411111111112, 51.34138055555557],
#  318: [12.377411111111112, 51.34138055555557],
#  319: [12.377411111111112, 51.34138055555557],
#  250: [12.388158333333335, 51.33492777777777],
#  249: [12.388158333333335, 51.33492777777777],
#  251: [12.388158333333335, 51.33492777777777],
#  774: [12.383433333333333, 51.339433333333346],
#  776: [12.383433333333333, 51.339433333333346],
#  775: [12.383433333333333, 51.339433333333346]}

# %%
df2
# Out:
#                                      cell  \
# 0   {'pci': 168, 'eci': -1, 'tac': 32208}
# 1   {'pci': 169, 'eci': -1, 'tac': 32208}
# 2   {'pci': 170, 'eci': -1, 'tac': 32208}
# 3   {'pci': 901, 'eci': -1, 'tac': 32208}
# 4   {'pci': 902, 'eci': -1, 'tac': 32208}
# 5   {'pci': 900, 'eci': -1, 'tac': 32208}
# 6   {'pci': 377, 'eci': -1, 'tac': 32208}
# 7   {'pci': 376, 'eci': -1, 'tac': 32208}
# 8   {'pci': 375, 'eci': -1, 'tac': 32208}
# 9   {'pci': 132, 'eci': -1, 'tac': 32208}
# 10  {'pci': 134, 'eci': -1, 'tac': 32208}
# 11  {'pci': 133, 'eci': -1, 'tac': 32208}
# 12  {'pci': 320, 'eci': -1, 'tac': 32208}
# 13  {'pci': 318, 'eci': -1, 'tac': 32208}
# 14  {'pci': 319, 'eci': -1, 'tac': 32208}
# 15  {'pci': 250, 'eci': -1, 'tac': 32208}
# 16  {'pci': 249, 'eci': -1, 'tac': 32208}
# 17  {'pci': 251, 'eci': -1, 'tac': 32208}
# 18  {'pci': 774, 'eci': -1, 'tac': 32208}
# 19  {'pci': 776, 'eci': -1, 'tac': 32208}
# 20  {'pci': 775, 'eci': -1, 'tac': 32208}
#
#                                      ant site_name  \
# 0   {'az': 180, 'el': 109, 'height': 30}    LY3558
# 1   {'az': 300, 'el': 109, 'height': 30}    LY3558
# 2    {'az': 60, 'el': 109, 'height': 30}    LY3558
# 3   {'az': 180, 'el': 110, 'height': 45}    LY0484
# 4   {'az': 300, 'el': 110, 'height': 45}    LY0484
# 5    {'az': 60, 'el': 110, 'height': 45}    LY0484
# 6    {'az': 60, 'el': 107, 'height': 42}    LY1094
# 7   {'az': 300, 'el': 107, 'height': 42}    LY1094
# 8   {'az': 180, 'el': 107, 'height': 42}    LY1094
# 9   {'az': 300, 'el': 109, 'height': 37}    LY2624
# 10   {'az': 60, 'el': 109, 'height': 37}    LY2624
# 11  {'az': 180, 'el': 109, 'height': 37}    LY2624
# 12   {'az': 60, 'el': 107, 'height': 35}    LY0494
# 13  {'az': 300, 'el': 107, 'height': 35}    LY0494
# 14  {'az': 180, 'el': 107, 'height': 35}    LY0494
# 15   {'az': 60, 'el': 114, 'height': 31}    LY0715
# 16  {'az': 180, 'el': 114, 'height': 31}    LY0715
# 17  {'az': 300, 'el': 114, 'height': 31}    LY0715
# 18   {'az': 60, 'el': 115, 'height': 47}    LY1038
# 19  {'az': 180, 'el': 115, 'height': 47}    LY1038
# 20  {'az': 300, 'el': 115, 'height': 47}    LY1038
#
#                                          pos
# 0   [12.367383333333331, 51.339830555555565]
# 1   [12.367383333333331, 51.339830555555565]
# 2   [12.367383333333331, 51.339830555555565]
# 3   [12.377183333333335, 51.347266666666656]
# 4   [12.377183333333335, 51.347266666666656]
# 5   [12.377183333333335, 51.347266666666656]
# 6    [12.371591666666669, 51.34234166666668]
# 7    [12.371591666666669, 51.34234166666668]
# 8    [12.371591666666669, 51.34234166666668]
# 9    [12.379552777777777, 51.34256111111111]
# 10   [12.379552777777777, 51.34256111111111]
# 11   [12.379552777777777, 51.34256111111111]
# 12   [12.377411111111112, 51.34138055555557]
# 13   [12.377411111111112, 51.34138055555557]
# 14   [12.377411111111112, 51.34138055555557]
# 15   [12.388158333333335, 51.33492777777777]
# 16   [12.388158333333335, 51.33492777777777]
# 17   [12.388158333333335, 51.33492777777777]
# 18  [12.383433333333333, 51.339433333333346]
# 19  [12.383433333333333, 51.339433333333346]
# 20  [12.383433333333333, 51.339433333333346]

# %%
data=pd.DataFrame()

# %%
x=np.array([])
for i in df_ue['id']:
    dic=df_ue.loc[i]['cell_info']
    powers={}
    pos=df_ue.loc[i]['pos']
    powers.update({'x':pos[0]})
    powers.update({'y':pos[1]})
    for i in dic:
        powers.update({i['pci']:i['dl_rx_power']})
    x=np.append(x,powers)

# %%
data = pd.DataFrame.from_records(x)

# %%
data
# Out:
#              x          y  168  169  170  901  902  900  377  376  ...  133  \
# 0    12.380854  51.339139 -131 -140 -114 -111 -140 -140 -118 -136  ...  -95
# 1    12.378348  51.340952 -137 -137 -108 -106 -135 -135 -107 -129  ...  -84
# 2    12.377739  51.339400 -126 -136 -109 -109 -139 -139 -117 -131  ...  -95
# 3    12.378550  51.338761 -125 -137 -112 -111 -141 -141 -120 -133  ...  -97
# 4    12.380950  51.339520 -132 -140 -113 -110 -140 -140 -117 -136  ...  -94
# ..         ...        ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...
# 295  12.380463  51.340135 -134 -140 -112 -109 -138 -138 -114 -134  ...  -89
# 296  12.381386  51.340308 -136 -141 -113 -109 -138 -138 -114 -136  ...  -91
# 297  12.378390  51.339786 -130 -137 -109 -108 -138 -138 -114 -131  ...  -92
# 298  12.381421  51.339225 -132 -141 -115 -111 -140 -140 -118 -137  ...  -96
# 299  12.380928  51.338149 -127 -141 -116 -113 -142 -142 -123 -138  ... -100
#
#      320  318  319  250  249  251  774  776  775
# 0   -113 -123  -97 -133 -135 -106 -112  -99  -87
# 1    -83  -98  -74 -138 -141 -112 -125 -125  -95
# 2   -115 -115  -85 -139 -139 -110 -125 -118  -98
# 3   -121 -121  -91 -137 -137 -108 -123 -109  -99
# 4   -109 -122  -97 -132 -136 -107 -111 -106  -83
# ..   ...  ...  ...  ...  ...  ...  ...  ...  ...
# 295 -102 -118  -95 -133 -137 -109 -115 -115  -85
# 296 -101 -121 -101 -130 -137 -109 -111 -111  -81
# 297 -113 -113  -83 -139 -139 -110 -123 -121  -95
# 298 -112 -124  -99 -131 -135 -106 -108  -95  -83
# 299 -121 -127  -99 -133 -133 -104 -116  -91 -102
#
# [300 rows x 23 columns]

# %%
noise=np.power(10,-103/10)
sectors=cell_list
cluster=sectors

df2=pd.DataFrame()
df2=bib.get_int(data,sectors,cluster)

# %%
df=df2.copy()

SINR_1_list=np.array([])
SINR_2_list=np.array([])
c_cell=np.array([])
s_cell=np.array([])
for i in np.arange(0, len(df)):
    p_r=df.loc[i,:]
    p_r=p_r[2:2+len(sectors)] #goes through file line by line and selects the line
    p_r=np.power(10, p_r/10) # calculate the linear values for capacity calculations
    p_r=p_r.sort_values(ascending=False) # sort values by their order
    a_r=np.sqrt(p_r) #calculate the amplitude
    index=p_r.index.values #Extract all index values 
    index=index.astype(np.int) #PCIen as integer
    a_r=np.array(a_r)
    p_r=np.array(p_r)
    inter=df.loc[i,'inter']
    pci_coord= index[1]
    
    SINR_1= p_r[0]/(np.sum(p_r[1:len(p_r)])+inter+noise) #one bs sending -> rest interference
    SINR_2= np.power(np.sum(a_r[0:2]),2)/(np.sum(p_r[2:len(p_r)])+inter+noise)
    print(SINR_1)
    print(SINR_2)
    SINR_1_list=np.append(SINR_1_list,10*np.log10(SINR_1)) #appends the calculated elements
    SINR_2_list=np.append(SINR_2_list,10*np.log10(SINR_2))
    s_cell=np.append(s_cell,index[0])
    c_cell=np.append(c_cell,index[1])
# Out:
# 1.3833553515304904
# 3.4633871854976763
# 2.078136194459609
# 5.165996739452877
# 2.766661307116615
# 6.626425071859931
# 0.9694273283475217
# 2.887894311954619
# 3.527967250437434
# 8.053805700859128
# 0.5162515176730542
# 2.0315997853353935
# 4.032629181391856
# 8.467442701380916
# 0.9090874960080354
# 2.3242029811462515
# 2.772634832650183
# 6.646220915796682
# 0.7223839994313688
# 1.9888182687661817
# 1.360218686645386
# 3.9072056433167135
# 0.4143577553083352
# 1.5255202644650898
# 28.57557915113287
# 48.40984408684805
# 0.6965465519968663
# 2.180500914282642
# 0.533666137091479
# 3.3134061029146444
# 4.0360443663603816
# 9.760977055991331
# 8.289168794831763
# 17.801402658974652
# 2.293546011289102
# 5.918862302143137
# 0.891792513698462
# 3.031775212556923
# 143.56873120343374
# 187.8987523314066
# 0.4123646327786621
# 1.7945756160614244
# 1.1504027135430481
# 3.1249594515631114
# 1.1360637743051802
# 3.0745920906720317
# 0.4951837270317746
# 1.6406263752714714
# 0.6208014944629106
# 3.2857778130468525
# 0.7317543311670486
# 2.323899531674603
# 1.1235630713472646
# 3.0309848678139963
# 1.7400634124923875
# 4.69652205862227
# 0.933175203248158
# 2.746835802178222
# 0.6977061423380465
# 3.129641123101969
# 1.8959278339621037
# 6.382329184618412
# 4.6015801810312675
# 8.958621443747157
# 0.39300432046205147
# 0.8767783809588465
# 3.5828496300991337
# 2.0505120693638075
# 4.4687418976769875
# 2.0058270099790727
# 4.9255199146364665
# 3.0376252768010192
# 9.028091923879922
# 6.791874743595023
# 15.423436865233091
# 0.8524359787423734
# 2.149682889757519
# 0.3005749493131859
# 1.194218825563755
# 0.8644714946854406
# 3.5061693065348685
# 14.708700477322363
# 31.307598848385666
# 1.166032162068038
# 3.716171553089176
# 2.7851285436010818
# 6.687730172250213
# 0.24106191002372607
# 1.2705221319502475
# 0.36685365254653773
# 1.851788443466371
# 1.4333458261547187
# 5.047403358999882
# 0.7642770279133938
# 2.4601033564051096
# 7.668658302513355
# 15.883211824990445
# 0.575639661760359
# 1.9864388879225072
# 27.44128249256379
# 45.76149214958111
# 9.820220302833532
# 19.759571363496846
# 0.7390253821912834
# 2.785286420917963
# 1.1472727105548428
# 2.4613401575158904
# 1.906477817928075
# 6.439647367701848
# 2.4055168908778333
# 5.487471609484502
# 0.5622144089263864
# 2.8052172950828327
# 2.1808709846620915
# 6.5147434009098575
# 0.5705166094878175
# 2.869940280549067
# 0.7784243834100502
# 2.180605181656597
# 0.4120530981580937
# 1.7927435215883865
# 0.47091039448177785
# 1.5416492524655803
# 0.9475697139269675
# 3.3025283030427564
# 8.103137152724702
# 15.11423725567026
# 0.9232612649766442
# 3.8831876937478857
# 3.840471776585096
# 10.80187691919579
# 2.4093445322443277
# 6.347805235336184
# 3.204109634859178
# 6.286953166491054
# 1.0735381824332124
# 2.528691560535414

# %%
s_cell=s_cell.astype(int)
c_cell=c_cell.astype(int)

# %%
df['JT_1 SINR [dB]']=SINR_1_list
df['JT_2 SINR [dB]']=SINR_2_list
df['PCI Serving']=s_cell
df['PCI Coord']=c_cell

# %%
df
# Out:
#              x          y  168  169  170  901  902  900  377  376  ...  249  \
# 0    12.380854  51.339139 -131 -140 -114 -111 -140 -140 -118 -136  ... -135
# 1    12.378348  51.340952 -137 -137 -108 -106 -135 -135 -107 -129  ... -141
# 2    12.377739  51.339400 -126 -136 -109 -109 -139 -139 -117 -131  ... -139
# 3    12.378550  51.338761 -125 -137 -112 -111 -141 -141 -120 -133  ... -137
# 4    12.380950  51.339520 -132 -140 -113 -110 -140 -140 -117 -136  ... -136
# ..         ...        ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...
# 295  12.380463  51.340135 -134 -140 -112 -109 -138 -138 -114 -134  ... -137
# 296  12.381386  51.340308 -136 -141 -113 -109 -138 -138 -114 -136  ... -137
# 297  12.378390  51.339786 -130 -137 -109 -108 -138 -138 -114 -131  ... -139
# 298  12.381421  51.339225 -132 -141 -115 -111 -140 -140 -118 -137  ... -135
# 299  12.380928  51.338149 -127 -141 -116 -113 -142 -142 -123 -138  ... -133
#
#      251  774  776  775         inter  JT_1 SINR [dB]  JT_2 SINR [dB]  \
# 0   -106 -112  -99  -87  6.961083e-10        1.409338        5.395010
# 1   -112 -125 -125  -95  9.553407e-09        3.176740        7.131541
# 2   -110 -125 -118  -98  5.464377e-10        4.419560        8.212793
# 3   -108 -123 -109  -99  3.846301e-10       -0.134847        4.605813
# 4   -107 -111 -106  -83  6.852466e-10        5.475245        9.060011
# ..   ...  ...  ...  ...           ...             ...             ...
# 295 -109 -115 -115  -85  1.687499e-09       -0.346754        5.891884
# 296 -109 -111 -111  -81  1.009095e-09        5.843846       10.334992
# 297 -110 -123 -121  -95  1.015031e-09        3.818989        8.026236
# 298 -106 -108  -95  -83  7.570413e-10        5.057074        7.984402
# 299 -104 -116  -91 -102  3.448987e-10        0.308175        4.028959
#
#      PCI Serving  PCI Coord
# 0            775        133
# 1            319        320
# 2            319        133
# 3            319        133
# 4            775        133
# ..           ...        ...
# 295          775        133
# 296          775        133
# 297          319        133
# 298          775        776
# 299          776        319
#
# [300 rows x 28 columns]

# %%
df1=df

# %%
df=pd.DataFrame()
df['x']=df1['x']
df['y']=df1['y']
df['PCI Serving']=df1['PCI Serving']
df['PCI Coord']=df1['PCI Coord']
df['JT_1 SINR [dB]']=df1['JT_1 SINR [dB]']
df['JT_2 SINR [dB]']=df1['JT_2 SINR [dB]']
df['usage']=np.zeros(len(df1))
df['id']=np.arange(0,len(df1))

# %%
df
# Out:
#              x          y  PCI Serving  PCI Coord  JT_1 SINR [dB]  \
# 0    12.380854  51.339139          775        133        1.409338
# 1    12.378348  51.340952          319        320        3.176740
# 2    12.377739  51.339400          319        133        4.419560
# 3    12.378550  51.338761          319        133       -0.134847
# 4    12.380950  51.339520          775        133        5.475245
# ..         ...        ...          ...        ...             ...
# 295  12.380463  51.340135          775        133       -0.346754
# 296  12.381386  51.340308          775        133        5.843846
# 297  12.378390  51.339786          319        133        3.818989
# 298  12.381421  51.339225          775        776        5.057074
# 299  12.380928  51.338149          776        319        0.308175
#
#      JT_2 SINR [dB]  usage   id
# 0          5.395010    0.0    0
# 1          7.131541    0.0    1
# 2          8.212793    0.0    2
# 3          4.605813    0.0    3
# 4          9.060011    0.0    4
# ..              ...    ...  ...
# 295        5.891884    0.0  295
# 296       10.334992    0.0  296
# 297        8.026236    0.0  297
# 298        7.984402    0.0  298
# 299        4.028959    0.0  299
#
# [300 rows x 8 columns]

# %%
#check if the number of users (positions) for the serving pci is >10
df_f=df.groupby('PCI Serving')
count=0
for i in df['PCI Serving'].unique():
    k=df_f.get_group(i)
    if(len(k)<10):
        cluster=np.delete(cluster,count) #delete cells with less than 10 positions
        df=df[df['PCI Serving']!=i]
    count+=1

# %%
df
# Out:
#              x          y  PCI Serving  PCI Coord  JT_1 SINR [dB]  \
# 0    12.380854  51.339139          775        133        1.409338
# 1    12.378348  51.340952          319        320        3.176740
# 2    12.377739  51.339400          319        133        4.419560
# 3    12.378550  51.338761          319        133       -0.134847
# 4    12.380950  51.339520          775        133        5.475245
# ..         ...        ...          ...        ...             ...
# 295  12.380463  51.340135          775        133       -0.346754
# 296  12.381386  51.340308          775        133        5.843846
# 297  12.378390  51.339786          319        133        3.818989
# 298  12.381421  51.339225          775        776        5.057074
# 299  12.380928  51.338149          776        319        0.308175
#
#      JT_2 SINR [dB]  usage   id
# 0          5.395010    0.0    0
# 1          7.131541    0.0    1
# 2          8.212793    0.0    2
# 3          4.605813    0.0    3
# 4          9.060011    0.0    4
# ..              ...    ...  ...
# 295        5.891884    0.0  295
# 296       10.334992    0.0  296
# 297        8.026236    0.0  297
# 298        7.984402    0.0  298
# 299        4.028959    0.0  299
#
# [297 rows x 8 columns]

# %%
df.to_csv('Prepro/Test-Data')
